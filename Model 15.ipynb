# %% [markdown]
# # Import Package Yang Dibutuhkan

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %% [markdown]
# # Ambil dan Baca File Dataset

# %%
df = pd.read_csv("DATASET/dataset rata-rata.csv", sep=';') # membaca dataset dari file CSV dengan pemisah titik koma
df['Tanggal'] = pd.to_datetime(df['Tanggal'], dayfirst=True) # ubah kolom 'Tanggal' menjadi tipe datetime dan mengatur format hari-bulan-tahun
df = df.sort_values('Tanggal') # urutkan data berdasarkan tanggal
df.set_index('Tanggal', inplace=True) # set kolom 'Tanggal' sebagai index

# %%
df.head() # menampilkan 5 baris pertama dari dataset
# Out:
#                Harga
# Tanggal
# 2018-01-02  122150.0
# 2018-01-03  126450.0
# 2018-01-04  107850.0
# 2018-01-05  121550.0
# 2018-01-08  121150.0

# %%
df.tail() # menampilkan 5 baris terakhir dari dataset
# Out:
#                Harga
# Tanggal
# 2025-05-26  156100.0
# 2025-05-27  156100.0
# 2025-05-28  156100.0
# 2025-05-29  156100.0
# 2025-05-30  156100.0

# %%
plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(df.index, df['Harga'], label='Harga') # plot harga daging sapi
plt.title('Harga Daging Sapi 2018-2025') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi

# %%
print(df['Harga'].describe())
# Out:
# count      1908.000000
# mean     141551.808176
# std       13421.208265
# min      102650.000000
# 25%      131350.000000
# 50%      135150.000000
# 75%      156650.000000
# max      189000.000000
# Name: Harga, dtype: float64

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Pengecekan Nilai Kosong

# %%
print('Jumlah nilai kosong:') # menampilkan jumlah nilai kosong
df.isnull().sum() # menampilkan jumlah nilai kosong pada setiap kolom
# Out:
# Jumlah nilai kosong:
# Harga    14
# dtype: int64

# %% [markdown]
# Pengecekan Nilai Duplikat

# %%
duplicate_dates = df.index.duplicated().sum() # menghitung jumlah tanggal duplikat pada index
print(f'Jumlah tanggal duplikat pada index: {duplicate_dates}') # menampilkan jumlah tanggal duplikat pada index
# Out:
# Jumlah tanggal duplikat pada index: 0

# %% [markdown]
# Penghapusan Nilai Kosong

# %%
df = df.dropna() # menghapus baris yang memiliki nilai kosong

# %%
df.isnull().sum() # menampilkan jumlah nilai kosong setelah penghapusan
# Out:
# Harga    0
# dtype: int64

# %% [markdown]
# Normalisasi data dengan MinMaxScaler

# %%
scaler = MinMaxScaler() # inisialisasi MinMaxScaler untuk normalisasi data
scaled_data = scaler.fit_transform(df[['Harga']]) # normalisasi data harga daging sapi

# %%
print('Data setelah normalisasi:') # menampilkan data setelah normalisasi
scaled_df = pd.DataFrame(scaled_data, index=df.index, columns=['Harga_Daging_Sapi']) # membuat DataFrame baru dengan data yang sudah dinormalisasi
scaled_df.head() # menampilkan 5 baris pertama dari data yang sudah dinormalisasi
# Out:
# Data setelah normalisasi:
#             Harga_Daging_Sapi
# Tanggal
# 2018-01-02           0.225825
# 2018-01-03           0.275622
# 2018-01-04           0.060220
# 2018-01-05           0.218877
# 2018-01-08           0.214244

# %% [markdown]
# ## Membuat Fitur dan Target Menggunakan Sliding Window

# %%
def create_dataset(dataset, time_step=30): # fungsi untuk membuat dataset dengan time step 30
    X, y = [], [] # inisialisasi list untuk fitur (X) dan target (y)
    for i in range(len(dataset) - time_step): # iterasi untuk membuat fitur dan target
        X.append(dataset[i:(i + time_step), 0]) # mengambil data dari indeks i sampai i + time_step
        y.append(dataset[i + time_step, 0]) # target adalah data pada indeks i + time_step
    return np.array(X), np.array(y) # mengembalikan fitur dan target sebagai array numpy
time_step = 30 # mendefinisikan time step untuk dataset
X, y = create_dataset(scaled_data, time_step) # membuat dataset dengan time step 30
X = X.reshape(X.shape[0], X.shape[1], 1) # mengubah bentuk X menjadi 3D array untuk LSTM input

# %% [markdown]
# # Membangun Model LSTM

# %% [markdown]
# Membagi Rasio Data Latih dan Uji

# %%
train_size = int(len(X) * 0.7) # mendefinisikan ukuran data latih sebagai 70% dari total data
X_train, X_test = X[:train_size], X[train_size:] # membagi data menjadi data latih dan data uji
y_train, y_test = y[:train_size], y[train_size:] # membagi target menjadi data latih dan data uji

# %% [markdown]
# Membangun Hidden Layer LSTM

# %%
model = Sequential() # inisialisasi model Sequential
model.add(LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], 1))) # menambahkan layer LSTM pertama dengan 128 unit dan return_sequences=True
model.add(Dropout(0.2)) # menambahkan layer Dropout untuk mengurangi overfitting
model.add(LSTM(128)) # menambahkan layer LSTM kedua dengan 128 unit
model.add(Dropout(0.2)) # menambahkan layer Dropout kedua
model.add(Dense(1)) # menambahkan layer Dense output dengan 1 unit
optimizer = Adam(learning_rate=0.05) # inisialisasi optimizer Adam dengan learning rate 0.05
model.compile(optimizer=optimizer, loss='mean_squared_error') # mengkompilasi model dengan loss function mean squared error
# Out:
# c:\Users\mfasa\Documents\Ngoding\Deep Learning\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Training Model

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1) # melatih model dengan data latih dan validasi, selama 100 epoch dengan batch size 32
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - loss: 9.0030 - val_loss: 0.0344
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0861 - val_loss: 0.0209
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0354 - val_loss: 0.0376
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0195 - val_loss: 0.0789
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0132 - val_loss: 0.0420
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0168 - val_loss: 0.0824
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0159 - val_loss: 0.0728
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0129 - val_loss: 0.0322
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0191 - val_loss: 0.0757
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0132 - val_loss: 0.0988
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0127 - val_loss: 0.0517
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0134 - val_loss: 0.0901
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0133 - val_loss: 0.0425
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0158 - val_loss: 0.0602
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0136 - val_loss: 0.1147
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0152 - val_loss: 0.1089
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0141 - val_loss: 0.0854
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0131 - val_loss: 0.0842
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0127 - val_loss: 0.0687
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0125 - val_loss: 0.1229
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0196 - val_loss: 0.0622
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0138 - val_loss: 0.0324
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0194 - val_loss: 0.0472
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0139 - val_loss: 0.0677
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0134 - val_loss: 0.0598
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0134 - val_loss: 0.1020
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0152 - val_loss: 0.0359
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0157 - val_loss: 0.0608
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0134 - val_loss: 0.0511
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0150 - val_loss: 0.0795
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0150 - val_loss: 0.0239
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0168 - val_loss: 0.0567
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0151 - val_loss: 0.0838
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0131 - val_loss: 0.0782
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0132 - val_loss: 0.1852
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0238 - val_loss: 0.0735
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0162 - val_loss: 0.0597
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0130 - val_loss: 0.0987
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0156 - val_loss: 0.1425
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0175 - val_loss: 0.0588
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0133 - val_loss: 0.0893
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0201 - val_loss: 0.0391
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0146 - val_loss: 0.0635
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0124 - val_loss: 0.0532
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0150 - val_loss: 0.0699
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0129 - val_loss: 0.0529
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0129 - val_loss: 0.0906
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0160 - val_loss: 0.1092
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0135 - val_loss: 0.0521
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0143 - val_loss: 0.0566
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0138 - val_loss: 0.0632
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0136 - val_loss: 0.0634
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0125 - val_loss: 0.0890
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0176 - val_loss: 0.0713
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0128 - val_loss: 0.0879
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0136 - val_loss: 0.0770
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0129 - val_loss: 0.0925
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0165 - val_loss: 0.0192
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0178 - val_loss: 0.0873
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0143 - val_loss: 0.0671
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0187 - val_loss: 0.0558
# Epoch 62/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0134 - val_loss: 0.0196
# Epoch 63/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0159 - val_loss: 0.1052
# Epoch 64/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0144 - val_loss: 0.0669
# Epoch 65/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0138 - val_loss: 0.0706
# Epoch 66/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0155 - val_loss: 0.1275
# Epoch 67/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0202 - val_loss: 0.0542
# Epoch 68/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0145 - val_loss: 0.1073
# Epoch 69/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0153 - val_loss: 0.0239
# Epoch 70/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0168 - val_loss: 0.0330
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0174 - val_loss: 0.0592
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0129 - val_loss: 0.1585
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0217 - val_loss: 0.0583
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0147 - val_loss: 0.0257
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0166 - val_loss: 0.0885
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0180 - val_loss: 0.0101
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0235 - val_loss: 0.0425
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0157 - val_loss: 0.0367
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0162 - val_loss: 0.1558
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0249 - val_loss: 0.0444
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0147 - val_loss: 0.1171
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0168 - val_loss: 0.1528
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0214 - val_loss: 0.0364
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0177 - val_loss: 0.0813
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0138 - val_loss: 0.1282
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0163 - val_loss: 0.0824
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0161 - val_loss: 0.0781
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0150 - val_loss: 0.0327
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0193 - val_loss: 0.0453
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0167 - val_loss: 0.0671
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0136 - val_loss: 0.0892
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0127 - val_loss: 0.1501
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0181 - val_loss: 0.1340
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0166 - val_loss: 0.1467
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0166 - val_loss: 0.1301
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0131 - val_loss: 0.0312
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0146 - val_loss: 0.1024
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0160 - val_loss: 0.0424
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0154 - val_loss: 0.0040
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0436 - val_loss: 0.0250

# %%
train_predict = model.predict(X_train) # melakukan prediksi pada data latih
test_predict = model.predict(X_test) # melakukan prediksi pada data uji
# Out:
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %% [markdown]
# # Visualisasi Hasil Training

# %%
train_predict = scaler.inverse_transform(train_predict) # mengembalikan skala prediksi data latih
test_predict = scaler.inverse_transform(test_predict) # mengembalikan skala prediksi data uji
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1)) # mengembalikan skala target data latih
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1)) # mengembalikan skala target data uji

# %%
train_dates = df.index[time_step:train_size + time_step] # menagmbil tanggal untuk data latih
test_dates = df.index[train_size + time_step:] # mengambil tanggal untuk data uji

plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(train_dates, y_train_inv, label='Data Training Asli') # plot data asli training
plt.plot(train_dates, train_predict, label='Prediksi Training') # plot prediksi training
plt.plot(test_dates, y_test_inv, label='Data Testing Asli') # plot data asli testing
plt.plot(test_dates, test_predict, label='Prediksi Testing') # plot prediksi testing
plt.legend() # menampilkan legenda
plt.title('Prediksi Harga Daging Sapi dengan LSTM') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik prediksi harga daging sapi

# %% [markdown]
# # Evaluasi Model

# %%
# Hitung MSE
mse = mean_squared_error(y_test_inv, test_predict) # Hitung Mean Squared Error (MSE)
print(f'Mean Squared Error (MSE): {mse}') # menampilkan MSE

# Hitung RMSE
rmse = np.sqrt(mse) # Hitung Root Mean Squared Error (RMSE)
print(f'Root Mean Squared Error (RMSE): {rmse}') # menampilkan RMSE

# Hitung MAE
mae = mean_absolute_error(y_test_inv, test_predict) # Hitung Mean Absolute Error (MAE)
print(f'Mean Absolute Error (MAE): {mae}') # menampilkan MAE

# Hitung MAPE
mape = np.mean(np.abs((y_test_inv - test_predict) / (y_test_inv + 1e-8))) * 100 # Hitung Mean Absolute Percentage Error (MAPE) dan menghindari pembagian dengan nol
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%') # menampilkan MAPE
# Out:
# Mean Squared Error (MSE): 186626562.55181193
# Root Mean Squared Error (RMSE): 13661.133282118724
# Mean Absolute Error (MAE): 13150.197334884751
# Mean Absolute Percentage Error (MAPE): 8.28%

# %% [markdown]
# # Prediksi 90 Hari Kedepan

# %% [markdown]
# Prediksi 90 hari ke depan (normalized)

# %%
future_steps = 90 # menentukan jumlah langkah prediksi ke depan
last_input = scaled_data[-time_step:].reshape(1, time_step, 1) # mengambil data terakhir untuk prediksi dan mengubah bentuknya menjadi 3D array
future_preds_90_norm = [] # inisialisasi list untuk menyimpan prediksi 90 hari ke depan

for _ in range(future_steps): # loop untuk melakukan prediksi 90 hari ke depan
    pred = model.predict(last_input, verbose=0) # melakukan prediksi dengan model
    future_preds_90_norm.append(pred[0, 0])  # menyimpan prediksi ke dalam list
    last_input = np.append(last_input[:, 1:, :], [[[pred[0, 0]]]], axis=1) # memperbarui input terakhir dengan prediksi baru

# %% [markdown]
# Denormalisasi hasil prediksi

# %%
future_preds_90_actual = scaler.inverse_transform(np.array(future_preds_90_norm).reshape(-1, 1)).flatten().astype(int) # denormalisasi hasil prediksi dan mengubahnya menjadi integer

# %% [markdown]
# Buat DataFrame untuk Tabel

# %%
last_date = df.index[-1] # mengambil tanggal terakhir dari data historis
future_dates_90 = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=future_steps) # membuat rentang tanggal untuk 90 hari ke depan

# Versi Normalized
df_future_90_norm = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga dinormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Normalized)': np.round(future_preds_90_norm, 6)
})

# Versi DENORMALIZED
df_future_90_actual = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga denormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Rp/Kg)': future_preds_90_actual
})

# Versi untuk plot/gabung (pakai index datetime)
df_future_90_plot = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan index datetime
    'Tanggal': future_dates_90,
    'Prediksi Harga Daging Sapi': future_preds_90_actual
}).set_index('Tanggal')

# %% [markdown]
# Gabungkan dengan data historis

# %%
df_all = pd.concat([ # menggabungkan DataFrame historis dengan prediksi 90 hari ke depan
    df[['Harga']], # mengambil kolom 'Harga_Daging_Sapi' dari DataFrame historis
    df_future_90_plot.rename(columns={'Prediksi Harga Daging Sapi': 'Harga'}) # mengganti nama kolom untuk konsistensi
])

# %% [markdown]
# Tampilkan tabel versi normalisasi dan denormalisasi

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Normalisasi):")
print(df_future_90_norm.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Normalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Normalized)
#   1 2025-05-31                                 0.488726
#   2 2025-06-01                                 0.488723
#   3 2025-06-02                                 0.488720
#   4 2025-06-03                                 0.488722
#   5 2025-06-04                                 0.488724
#   6 2025-06-05                                 0.488724
#   7 2025-06-06                                 0.488724
#   8 2025-06-07                                 0.488723
#   9 2025-06-08                                 0.488723
#  10 2025-06-09                                 0.488723
#  11 2025-06-10                                 0.488724
#  12 2025-06-11                                 0.488724
#  13 2025-06-12                                 0.488724
#  14 2025-06-13                                 0.488724
#  15 2025-06-14                                 0.488724
#  16 2025-06-15                                 0.488724
#  17 2025-06-16                                 0.488724
#  18 2025-06-17                                 0.488724
#  19 2025-06-18                                 0.488724
#  20 2025-06-19                                 0.488724
#  21 2025-06-20                                 0.488724
#  22 2025-06-21                                 0.488724
#  23 2025-06-22                                 0.488724
#  24 2025-06-23                                 0.488724
#  25 2025-06-24                                 0.488724
#  26 2025-06-25                                 0.488724
#  27 2025-06-26                                 0.488724
#  28 2025-06-27                                 0.488724
#  29 2025-06-28                                 0.488724
#  30 2025-06-29                                 0.488721
#  31 2025-06-30                                 0.488720
#  32 2025-07-01                                 0.488720
#  33 2025-07-02                                 0.488720
#  34 2025-07-03                                 0.488720
#  35 2025-07-04                                 0.488720
#  36 2025-07-05                                 0.488720
#  37 2025-07-06                                 0.488720
#  38 2025-07-07                                 0.488720
#  39 2025-07-08                                 0.488720
#  40 2025-07-09                                 0.488720
#  41 2025-07-10                                 0.488720
#  42 2025-07-11                                 0.488720
#  43 2025-07-12                                 0.488720
#  44 2025-07-13                                 0.488720
#  45 2025-07-14                                 0.488720
#  46 2025-07-15                                 0.488720
#  47 2025-07-16                                 0.488720
#  48 2025-07-17                                 0.488720
#  49 2025-07-18                                 0.488720
#  50 2025-07-19                                 0.488720
#  51 2025-07-20                                 0.488720
#  52 2025-07-21                                 0.488720
#  53 2025-07-22                                 0.488720
#  54 2025-07-23                                 0.488720
#  55 2025-07-24                                 0.488720
#  56 2025-07-25                                 0.488720
#  57 2025-07-26                                 0.488720
#  58 2025-07-27                                 0.488720
#  59 2025-07-28                                 0.488720
#  60 2025-07-29                                 0.488720
#  61 2025-07-30                                 0.488720
#  62 2025-07-31                                 0.488720
#  63 2025-08-01                                 0.488720
#  64 2025-08-02                                 0.488720
#  65 2025-08-03                                 0.488720
#  66 2025-08-04                                 0.488720
#  67 2025-08-05                                 0.488720
#  68 2025-08-06                                 0.488720
#  69 2025-08-07                                 0.488720
#  70 2025-08-08                                 0.488720
#  71 2025-08-09                                 0.488720
#  72 2025-08-10                                 0.488720
#  73 2025-08-11                                 0.488720
#  74 2025-08-12                                 0.488720
#  75 2025-08-13                                 0.488720
#  76 2025-08-14                                 0.488720
#  77 2025-08-15                                 0.488720
#  78 2025-08-16                                 0.488720
#  79 2025-08-17                                 0.488720
#  80 2025-08-18                                 0.488720
#  81 2025-08-19                                 0.488720
#  82 2025-08-20                                 0.488720
#  83 2025-08-21                                 0.488720
#  84 2025-08-22                                 0.488720
#  85 2025-08-23                                 0.488720
#  86 2025-08-24                                 0.488720
#  87 2025-08-25                                 0.488720
#  88 2025-08-26                                 0.488720
#  89 2025-08-27                                 0.488720
#  90 2025-08-28                                 0.488720

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Denormalisasi):")
print(df_future_90_actual.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Denormalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Rp/Kg)
#   1 2025-05-31                              144851
#   2 2025-06-01                              144851
#   3 2025-06-02                              144851
#   4 2025-06-03                              144851
#   5 2025-06-04                              144851
#   6 2025-06-05                              144851
#   7 2025-06-06                              144851
#   8 2025-06-07                              144851
#   9 2025-06-08                              144851
#  10 2025-06-09                              144851
#  11 2025-06-10                              144851
#  12 2025-06-11                              144851
#  13 2025-06-12                              144851
#  14 2025-06-13                              144851
#  15 2025-06-14                              144851
#  16 2025-06-15                              144851
#  17 2025-06-16                              144851
#  18 2025-06-17                              144851
#  19 2025-06-18                              144851
#  20 2025-06-19                              144851
#  21 2025-06-20                              144851
#  22 2025-06-21                              144851
#  23 2025-06-22                              144851
#  24 2025-06-23                              144851
#  25 2025-06-24                              144851
#  26 2025-06-25                              144851
#  27 2025-06-26                              144851
#  28 2025-06-27                              144851
#  29 2025-06-28                              144851
#  30 2025-06-29                              144851
#  31 2025-06-30                              144850
#  32 2025-07-01                              144850
#  33 2025-07-02                              144850
#  34 2025-07-03                              144850
#  35 2025-07-04                              144850
#  36 2025-07-05                              144850
#  37 2025-07-06                              144850
#  38 2025-07-07                              144850
#  39 2025-07-08                              144850
#  40 2025-07-09                              144850
#  41 2025-07-10                              144850
#  42 2025-07-11                              144850
#  43 2025-07-12                              144850
#  44 2025-07-13                              144850
#  45 2025-07-14                              144850
#  46 2025-07-15                              144850
#  47 2025-07-16                              144850
#  48 2025-07-17                              144850
#  49 2025-07-18                              144850
#  50 2025-07-19                              144850
#  51 2025-07-20                              144850
#  52 2025-07-21                              144850
#  53 2025-07-22                              144850
#  54 2025-07-23                              144850
#  55 2025-07-24                              144850
#  56 2025-07-25                              144850
#  57 2025-07-26                              144850
#  58 2025-07-27                              144850
#  59 2025-07-28                              144850
#  60 2025-07-29                              144850
#  61 2025-07-30                              144850
#  62 2025-07-31                              144850
#  63 2025-08-01                              144850
#  64 2025-08-02                              144850
#  65 2025-08-03                              144850
#  66 2025-08-04                              144850
#  67 2025-08-05                              144850
#  68 2025-08-06                              144850
#  69 2025-08-07                              144850
#  70 2025-08-08                              144850
#  71 2025-08-09                              144850
#  72 2025-08-10                              144850
#  73 2025-08-11                              144850
#  74 2025-08-12                              144850
#  75 2025-08-13                              144850
#  76 2025-08-14                              144850
#  77 2025-08-15                              144850
#  78 2025-08-16                              144850
#  79 2025-08-17                              144850
#  80 2025-08-18                              144850
#  81 2025-08-19                              144850
#  82 2025-08-20                              144850
#  83 2025-08-21                              144850
#  84 2025-08-22                              144850
#  85 2025-08-23                              144850
#  86 2025-08-24                              144850
#  87 2025-08-25                              144850
#  88 2025-08-26                              144850
#  89 2025-08-27                              144850
#  90 2025-08-28                              144850

# %% [markdown]
# Tampilkan plot harga historis 90 hari + prediksi 90 hari ke depan

# %%
window_hist = 90 # menentukan jumlah hari historis yang akan ditampilkan
last_hist_dates = df.index[-window_hist:] # mengambil tanggal historis terakhir
last_hist_prices = df['Harga'].iloc[-window_hist:] # mengambil harga historis terakhir

future_dates_90_plot = df_future_90_plot.index # mengambil tanggal untuk prediksi 90 hari ke depan
future_prices_90_plot = df_future_90_plot['Prediksi Harga Daging Sapi'] # mengambil harga prediksi 90 hari ke depan

plt.figure(figsize=(14,7)) # plot ukuran grafik
plt.plot(last_hist_dates, last_hist_prices, label=f'Harga Asli {window_hist} Hari Terakhir', color='blue') # plot harga historis terakhir
plt.plot(future_dates_90_plot, future_prices_90_plot, label='Prediksi 90 Hari Kedepan', color='orange', linestyle='--') # plot prediksi 90 hari ke depan
plt.axvline(x=last_hist_dates[-1], color='grey', linestyle=':', label='Batas Data Historis') # garis vertikal untuk batas data historis
plt.title(f'Harga Daging Sapi: {window_hist} Hari Terakhir & Prediksi 90 Hari Kedepan') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.xticks(rotation=45) # rotasi label sumbu x agar lebih mudah dibaca
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi dengan prediksi 90 hari ke depan

# %% [markdown]
# # Import Package Yang Dibutuhkan

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %% [markdown]
# # Ambil dan Baca File Dataset

# %%
df = pd.read_csv("DATASET/dataset rata-rata.csv", sep=';') # membaca dataset dari file CSV dengan pemisah titik koma
df['Tanggal'] = pd.to_datetime(df['Tanggal'], dayfirst=True) # ubah kolom 'Tanggal' menjadi tipe datetime dan mengatur format hari-bulan-tahun
df = df.sort_values('Tanggal') # urutkan data berdasarkan tanggal
df.set_index('Tanggal', inplace=True) # set kolom 'Tanggal' sebagai index

# %%
df.head() # menampilkan 5 baris pertama dari dataset
# Out:
#                Harga
# Tanggal
# 2018-01-02  122150.0
# 2018-01-03  126450.0
# 2018-01-04  107850.0
# 2018-01-05  121550.0
# 2018-01-08  121150.0

# %%
df.tail() # menampilkan 5 baris terakhir dari dataset
# Out:
#                Harga
# Tanggal
# 2025-05-26  156100.0
# 2025-05-27  156100.0
# 2025-05-28  156100.0
# 2025-05-29  156100.0
# 2025-05-30  156100.0

# %%
plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(df.index, df['Harga'], label='Harga') # plot harga daging sapi
plt.title('Harga Daging Sapi 2018-2025') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi

# %%
print(df['Harga'].describe())
# Out:
# count      1908.000000
# mean     141551.808176
# std       13421.208265
# min      102650.000000
# 25%      131350.000000
# 50%      135150.000000
# 75%      156650.000000
# max      189000.000000
# Name: Harga, dtype: float64

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Pengecekan Nilai Kosong

# %%
print('Jumlah nilai kosong:') # menampilkan jumlah nilai kosong
df.isnull().sum() # menampilkan jumlah nilai kosong pada setiap kolom
# Out:
# Jumlah nilai kosong:
# Harga    14
# dtype: int64

# %% [markdown]
# Pengecekan Nilai Duplikat

# %%
duplicate_dates = df.index.duplicated().sum() # menghitung jumlah tanggal duplikat pada index
print(f'Jumlah tanggal duplikat pada index: {duplicate_dates}') # menampilkan jumlah tanggal duplikat pada index
# Out:
# Jumlah tanggal duplikat pada index: 0

# %% [markdown]
# Penghapusan Nilai Kosong

# %%
df = df.dropna() # menghapus baris yang memiliki nilai kosong

# %%
df.isnull().sum() # menampilkan jumlah nilai kosong setelah penghapusan
# Out:
# Harga    0
# dtype: int64

# %% [markdown]
# Normalisasi data dengan MinMaxScaler

# %%
scaler = MinMaxScaler() # inisialisasi MinMaxScaler untuk normalisasi data
scaled_data = scaler.fit_transform(df[['Harga']]) # normalisasi data harga daging sapi

# %%
print('Data setelah normalisasi:') # menampilkan data setelah normalisasi
scaled_df = pd.DataFrame(scaled_data, index=df.index, columns=['Harga_Daging_Sapi']) # membuat DataFrame baru dengan data yang sudah dinormalisasi
scaled_df.head() # menampilkan 5 baris pertama dari data yang sudah dinormalisasi
# Out:
# Data setelah normalisasi:
#             Harga_Daging_Sapi
# Tanggal
# 2018-01-02           0.225825
# 2018-01-03           0.275622
# 2018-01-04           0.060220
# 2018-01-05           0.218877
# 2018-01-08           0.214244

# %% [markdown]
# ## Membuat Fitur dan Target Menggunakan Sliding Window

# %%
def create_dataset(dataset, time_step=30): # fungsi untuk membuat dataset dengan time step 30
    X, y = [], [] # inisialisasi list untuk fitur (X) dan target (y)
    for i in range(len(dataset) - time_step): # iterasi untuk membuat fitur dan target
        X.append(dataset[i:(i + time_step), 0]) # mengambil data dari indeks i sampai i + time_step
        y.append(dataset[i + time_step, 0]) # target adalah data pada indeks i + time_step
    return np.array(X), np.array(y) # mengembalikan fitur dan target sebagai array numpy
time_step = 30 # mendefinisikan time step untuk dataset
X, y = create_dataset(scaled_data, time_step) # membuat dataset dengan time step 30
X = X.reshape(X.shape[0], X.shape[1], 1) # mengubah bentuk X menjadi 3D array untuk LSTM input

# %% [markdown]
# # Membangun Model LSTM

# %% [markdown]
# Membagi Rasio Data Latih dan Uji

# %%
train_size = int(len(X) * 0.9) # mendefinisikan ukuran data latih sebagai 90% dari total data
X_train, X_test = X[:train_size], X[train_size:] # membagi data menjadi data latih dan data uji
y_train, y_test = y[:train_size], y[train_size:] # membagi target menjadi data latih dan data uji

# %% [markdown]
# Membangun Hidden Layer LSTM

# %%
model = Sequential() # inisialisasi model Sequential
model.add(LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], 1))) # menambahkan layer LSTM pertama dengan 64 unit dan return_sequences=True
model.add(Dropout(0.2)) # menambahkan layer Dropout untuk mengurangi overfitting
model.add(LSTM(64)) # menambahkan layer LSTM kedua dengan 64 unit
model.add(Dropout(0.2)) # menambahkan layer Dropout kedua
model.add(Dense(1)) # menambahkan layer Dense output dengan 1 unit
optimizer = Adam(learning_rate=0.01) # inisialisasi optimizer Adam dengan learning rate 0.01
model.compile(optimizer=optimizer, loss='mean_squared_error') # mengkompilasi model dengan loss function mean squared error
# Out:
# c:\Users\mfasa\Documents\Ngoding\Deep Learning\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Training Model

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1) # melatih model dengan data latih dan validasi, selama 100 epoch dengan batch size 32
# Out:
# Epoch 1/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 0.0539 - val_loss: 0.0020
# Epoch 2/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 3/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 4/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 5/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 6/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 7/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 8/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 9/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 10/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 11/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 12/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 13/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 14/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 15/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 16/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 17/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 18/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 19/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 20/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 21/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 22/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 23/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 24/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 25/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 26/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 27/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 28/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 29/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 30/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 31/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 32/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 33/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 34/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 35/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 36/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 37/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 38/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 39/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 40/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 41/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 42/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 43/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 44/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 45/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 46/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 47/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 48/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 49/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 50/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 51/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 52/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 53/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 54/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 55/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 56/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 57/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 58/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 59/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 60/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 61/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 62/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 63/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 64/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 65/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 66/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 67/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 68/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 69/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 70/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 71/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 72/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 73/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 74/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 75/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 76/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 77/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 78/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 79/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 80/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 81/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 82/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 83/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 84/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 85/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 86/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 87/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 88/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 89/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 90/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 91/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 92/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 93/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 94/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 95/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 96/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 97/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 98/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 99/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 100/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 0.0013

# %%
train_predict = model.predict(X_train) # melakukan prediksi pada data latih
test_predict = model.predict(X_test) # melakukan prediksi pada data uji
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %% [markdown]
# # Visualisasi Hasil Training

# %%
train_predict = scaler.inverse_transform(train_predict) # mengembalikan skala prediksi data latih
test_predict = scaler.inverse_transform(test_predict) # mengembalikan skala prediksi data uji
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1)) # mengembalikan skala target data latih
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1)) # mengembalikan skala target data uji

# %%
train_dates = df.index[time_step:train_size + time_step] # menagmbil tanggal untuk data latih
test_dates = df.index[train_size + time_step:] # mengambil tanggal untuk data uji

plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(train_dates, y_train_inv, label='Data Training Asli') # plot data asli training
plt.plot(train_dates, train_predict, label='Prediksi Training') # plot prediksi training
plt.plot(test_dates, y_test_inv, label='Data Testing Asli') # plot data asli testing
plt.plot(test_dates, test_predict, label='Prediksi Testing') # plot prediksi testing
plt.legend() # menampilkan legenda
plt.title('Prediksi Harga Daging Sapi dengan LSTM') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik prediksi harga daging sapi

# %% [markdown]
# # Evaluasi Model

# %%
# Hitung MSE
mse = mean_squared_error(y_test_inv, test_predict) # Hitung Mean Squared Error (MSE)
print(f'Mean Squared Error (MSE): {mse}') # menampilkan MSE

# Hitung RMSE
rmse = np.sqrt(mse) # Hitung Root Mean Squared Error (RMSE)
print(f'Root Mean Squared Error (RMSE): {rmse}') # menampilkan RMSE

# Hitung MAE
mae = mean_absolute_error(y_test_inv, test_predict) # Hitung Mean Absolute Error (MAE)
print(f'Mean Absolute Error (MAE): {mae}') # menampilkan MAE

# Hitung MAPE
mape = np.mean(np.abs((y_test_inv - test_predict) / (y_test_inv + 1e-8))) * 100 # Hitung Mean Absolute Percentage Error (MAPE) dan menghindari pembagian dengan nol
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%') # menampilkan MAPE
# Out:
# Mean Squared Error (MSE): 9740107.714195738
# Root Mean Squared Error (RMSE): 3120.914563745015
# Mean Absolute Error (MAE): 2101.236120345745
# Mean Absolute Percentage Error (MAPE): 1.34%

# %% [markdown]
# # Prediksi 90 Hari Kedepan

# %% [markdown]
# Prediksi 90 hari ke depan (normalized)

# %%
future_steps = 90 # menentukan jumlah langkah prediksi ke depan
last_input = scaled_data[-time_step:].reshape(1, time_step, 1) # mengambil data terakhir untuk prediksi dan mengubah bentuknya menjadi 3D array
future_preds_90_norm = [] # inisialisasi list untuk menyimpan prediksi 90 hari ke depan

for _ in range(future_steps): # loop untuk melakukan prediksi 90 hari ke depan
    pred = model.predict(last_input, verbose=0) # melakukan prediksi dengan model
    future_preds_90_norm.append(pred[0, 0])  # menyimpan prediksi ke dalam list
    last_input = np.append(last_input[:, 1:, :], [[[pred[0, 0]]]], axis=1) # memperbarui input terakhir dengan prediksi baru

# %% [markdown]
# Denormalisasi hasil prediksi

# %%
future_preds_90_actual = scaler.inverse_transform(np.array(future_preds_90_norm).reshape(-1, 1)).flatten().astype(int) # denormalisasi hasil prediksi dan mengubahnya menjadi integer

# %% [markdown]
# Buat DataFrame untuk Tabel

# %%
last_date = df.index[-1] # mengambil tanggal terakhir dari data historis
future_dates_90 = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=future_steps) # membuat rentang tanggal untuk 90 hari ke depan

# Versi Normalized
df_future_90_norm = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga dinormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Normalized)': np.round(future_preds_90_norm, 6)
})

# Versi DENORMALIZED
df_future_90_actual = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga denormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Rp/Kg)': future_preds_90_actual
})

# Versi untuk plot/gabung (pakai index datetime)
df_future_90_plot = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan index datetime
    'Tanggal': future_dates_90,
    'Prediksi Harga Daging Sapi': future_preds_90_actual
}).set_index('Tanggal')

# %% [markdown]
# Gabungkan dengan data historis

# %%
df_all = pd.concat([ # menggabungkan DataFrame historis dengan prediksi 90 hari ke depan
    df[['Harga']], # mengambil kolom 'Harga_Daging_Sapi' dari DataFrame historis
    df_future_90_plot.rename(columns={'Prediksi Harga Daging Sapi': 'Harga'}) # mengganti nama kolom untuk konsistensi
])

# %% [markdown]
# Tampilkan tabel versi normalisasi dan denormalisasi

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Normalisasi):")
print(df_future_90_norm.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Normalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Normalized)
#   1 2025-05-31                                 0.608933
#   2 2025-06-01                                 0.604224
#   3 2025-06-02                                 0.599753
#   4 2025-06-03                                 0.596544
#   5 2025-06-04                                 0.593664
#   6 2025-06-05                                 0.590877
#   7 2025-06-06                                 0.588317
#   8 2025-06-07                                 0.586060
#   9 2025-06-08                                 0.584054
#  10 2025-06-09                                 0.582267
#  11 2025-06-10                                 0.580677
#  12 2025-06-11                                 0.579269
#  13 2025-06-12                                 0.578022
#  14 2025-06-13                                 0.576919
#  15 2025-06-14                                 0.575944
#  16 2025-06-15                                 0.575083
#  17 2025-06-16                                 0.574322
#  18 2025-06-17                                 0.573649
#  19 2025-06-18                                 0.573054
#  20 2025-06-19                                 0.572528
#  21 2025-06-20                                 0.572064
#  22 2025-06-21                                 0.571652
#  23 2025-06-22                                 0.571288
#  24 2025-06-23                                 0.570966
#  25 2025-06-24                                 0.570681
#  26 2025-06-25                                 0.570428
#  27 2025-06-26                                 0.570203
#  28 2025-06-27                                 0.570004
#  29 2025-06-28                                 0.569828
#  30 2025-06-29                                 0.569671
#  31 2025-06-30                                 0.569532
#  32 2025-07-01                                 0.569409
#  33 2025-07-02                                 0.569299
#  34 2025-07-03                                 0.569201
#  35 2025-07-04                                 0.569115
#  36 2025-07-05                                 0.569038
#  37 2025-07-06                                 0.568969
#  38 2025-07-07                                 0.568908
#  39 2025-07-08                                 0.568854
#  40 2025-07-09                                 0.568806
#  41 2025-07-10                                 0.568763
#  42 2025-07-11                                 0.568725
#  43 2025-07-12                                 0.568691
#  44 2025-07-13                                 0.568661
#  45 2025-07-14                                 0.568634
#  46 2025-07-15                                 0.568611
#  47 2025-07-16                                 0.568589
#  48 2025-07-17                                 0.568570
#  49 2025-07-18                                 0.568554
#  50 2025-07-19                                 0.568539
#  51 2025-07-20                                 0.568525
#  52 2025-07-21                                 0.568513
#  53 2025-07-22                                 0.568503
#  54 2025-07-23                                 0.568494
#  55 2025-07-24                                 0.568485
#  56 2025-07-25                                 0.568478
#  57 2025-07-26                                 0.568471
#  58 2025-07-27                                 0.568465
#  59 2025-07-28                                 0.568460
#  60 2025-07-29                                 0.568455
#  61 2025-07-30                                 0.568451
#  62 2025-07-31                                 0.568447
#  63 2025-08-01                                 0.568444
#  64 2025-08-02                                 0.568441
#  65 2025-08-03                                 0.568438
#  66 2025-08-04                                 0.568436
#  67 2025-08-05                                 0.568434
#  68 2025-08-06                                 0.568432
#  69 2025-08-07                                 0.568431
#  70 2025-08-08                                 0.568429
#  71 2025-08-09                                 0.568428
#  72 2025-08-10                                 0.568427
#  73 2025-08-11                                 0.568426
#  74 2025-08-12                                 0.568425
#  75 2025-08-13                                 0.568424
#  76 2025-08-14                                 0.568423
#  77 2025-08-15                                 0.568423
#  78 2025-08-16                                 0.568422
#  79 2025-08-17                                 0.568422
#  80 2025-08-18                                 0.568421
#  81 2025-08-19                                 0.568421
#  82 2025-08-20                                 0.568420
#  83 2025-08-21                                 0.568420
#  84 2025-08-22                                 0.568420
#  85 2025-08-23                                 0.568419
#  86 2025-08-24                                 0.568419
#  87 2025-08-25                                 0.568419
#  88 2025-08-26                                 0.568419
#  89 2025-08-27                                 0.568419
#  90 2025-08-28                                 0.568418

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Denormalisasi):")
print(df_future_90_actual.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Denormalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Rp/Kg)
#   1 2025-05-31                              155231
#   2 2025-06-01                              154824
#   3 2025-06-02                              154438
#   4 2025-06-03                              154161
#   5 2025-06-04                              153912
#   6 2025-06-05                              153672
#   7 2025-06-06                              153451
#   8 2025-06-07                              153256
#   9 2025-06-08                              153083
#  10 2025-06-09                              152928
#  11 2025-06-10                              152791
#  12 2025-06-11                              152669
#  13 2025-06-12                              152562
#  14 2025-06-13                              152466
#  15 2025-06-14                              152382
#  16 2025-06-15                              152308
#  17 2025-06-16                              152242
#  18 2025-06-17                              152184
#  19 2025-06-18                              152133
#  20 2025-06-19                              152087
#  21 2025-06-20                              152047
#  22 2025-06-21                              152012
#  23 2025-06-22                              151980
#  24 2025-06-23                              151952
#  25 2025-06-24                              151928
#  26 2025-06-25                              151906
#  27 2025-06-26                              151887
#  28 2025-06-27                              151869
#  29 2025-06-28                              151854
#  30 2025-06-29                              151841
#  31 2025-06-30                              151829
#  32 2025-07-01                              151818
#  33 2025-07-02                              151808
#  34 2025-07-03                              151800
#  35 2025-07-04                              151793
#  36 2025-07-05                              151786
#  37 2025-07-06                              151780
#  38 2025-07-07                              151775
#  39 2025-07-08                              151770
#  40 2025-07-09                              151766
#  41 2025-07-10                              151762
#  42 2025-07-11                              151759
#  43 2025-07-12                              151756
#  44 2025-07-13                              151753
#  45 2025-07-14                              151751
#  46 2025-07-15                              151749
#  47 2025-07-16                              151747
#  48 2025-07-17                              151746
#  49 2025-07-18                              151744
#  50 2025-07-19                              151743
#  51 2025-07-20                              151742
#  52 2025-07-21                              151741
#  53 2025-07-22                              151740
#  54 2025-07-23                              151739
#  55 2025-07-24                              151738
#  56 2025-07-25                              151738
#  57 2025-07-26                              151737
#  58 2025-07-27                              151736
#  59 2025-07-28                              151736
#  60 2025-07-29                              151736
#  61 2025-07-30                              151735
#  62 2025-07-31                              151735
#  63 2025-08-01                              151735
#  64 2025-08-02                              151734
#  65 2025-08-03                              151734
#  66 2025-08-04                              151734
#  67 2025-08-05                              151734
#  68 2025-08-06                              151734
#  69 2025-08-07                              151733
#  70 2025-08-08                              151733
#  71 2025-08-09                              151733
#  72 2025-08-10                              151733
#  73 2025-08-11                              151733
#  74 2025-08-12                              151733
#  75 2025-08-13                              151733
#  76 2025-08-14                              151733
#  77 2025-08-15                              151733
#  78 2025-08-16                              151733
#  79 2025-08-17                              151733
#  80 2025-08-18                              151733
#  81 2025-08-19                              151733
#  82 2025-08-20                              151733
#  83 2025-08-21                              151733
#  84 2025-08-22                              151733
#  85 2025-08-23                              151733
#  86 2025-08-24                              151733
#  87 2025-08-25                              151732
#  88 2025-08-26                              151732
#  89 2025-08-27                              151732
#  90 2025-08-28                              151732

# %% [markdown]
# Tampilkan plot harga historis 90 hari + prediksi 90 hari ke depan

# %%
window_hist = 90 # menentukan jumlah hari historis yang akan ditampilkan
last_hist_dates = df.index[-window_hist:] # mengambil tanggal historis terakhir
last_hist_prices = df['Harga'].iloc[-window_hist:] # mengambil harga historis terakhir

future_dates_90_plot = df_future_90_plot.index # mengambil tanggal untuk prediksi 90 hari ke depan
future_prices_90_plot = df_future_90_plot['Prediksi Harga Daging Sapi'] # mengambil harga prediksi 90 hari ke depan

plt.figure(figsize=(14,7)) # plot ukuran grafik
plt.plot(last_hist_dates, last_hist_prices, label=f'Harga Asli {window_hist} Hari Terakhir', color='blue') # plot harga historis terakhir
plt.plot(future_dates_90_plot, future_prices_90_plot, label='Prediksi 90 Hari Kedepan', color='orange', linestyle='--') # plot prediksi 90 hari ke depan
plt.axvline(x=last_hist_dates[-1], color='grey', linestyle=':', label='Batas Data Historis') # garis vertikal untuk batas data historis
plt.title(f'Harga Daging Sapi: {window_hist} Hari Terakhir & Prediksi 90 Hari Kedepan') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.xticks(rotation=45) # rotasi label sumbu x agar lebih mudah dibaca
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi dengan prediksi 90 hari ke depan

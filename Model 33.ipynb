# %% [markdown]
# # Import Package Yang Dibutuhkan

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %% [markdown]
# # Ambil dan Baca File Dataset

# %%
df = pd.read_csv("DATASET/dataset rata-rata.csv", sep=';') # membaca dataset dari file CSV dengan pemisah titik koma
df['Tanggal'] = pd.to_datetime(df['Tanggal'], dayfirst=True) # ubah kolom 'Tanggal' menjadi tipe datetime dan mengatur format hari-bulan-tahun
df = df.sort_values('Tanggal') # urutkan data berdasarkan tanggal
df.set_index('Tanggal', inplace=True) # set kolom 'Tanggal' sebagai index

# %%
df.head() # menampilkan 5 baris pertama dari dataset
# Out:
#                Harga
# Tanggal
# 2018-01-02  122150.0
# 2018-01-03  126450.0
# 2018-01-04  107850.0
# 2018-01-05  121550.0
# 2018-01-08  121150.0

# %%
df.tail() # menampilkan 5 baris terakhir dari dataset
# Out:
#                Harga
# Tanggal
# 2025-05-26  156100.0
# 2025-05-27  156100.0
# 2025-05-28  156100.0
# 2025-05-29  156100.0
# 2025-05-30  156100.0

# %%
plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(df.index, df['Harga'], label='Harga') # plot harga daging sapi
plt.title('Harga Daging Sapi 2018-2025') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi

# %%
print(df['Harga'].describe())
# Out:
# count      1908.000000
# mean     141551.808176
# std       13421.208265
# min      102650.000000
# 25%      131350.000000
# 50%      135150.000000
# 75%      156650.000000
# max      189000.000000
# Name: Harga, dtype: float64

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Pengecekan Nilai Kosong

# %%
print('Jumlah nilai kosong:') # menampilkan jumlah nilai kosong
df.isnull().sum() # menampilkan jumlah nilai kosong pada setiap kolom
# Out:
# Jumlah nilai kosong:
# Harga    14
# dtype: int64

# %% [markdown]
# Pengecekan Nilai Duplikat

# %%
duplicate_dates = df.index.duplicated().sum() # menghitung jumlah tanggal duplikat pada index
print(f'Jumlah tanggal duplikat pada index: {duplicate_dates}') # menampilkan jumlah tanggal duplikat pada index
# Out:
# Jumlah tanggal duplikat pada index: 0

# %% [markdown]
# Penghapusan Nilai Kosong

# %%
df = df.dropna() # menghapus baris yang memiliki nilai kosong

# %%
df.isnull().sum() # menampilkan jumlah nilai kosong setelah penghapusan
# Out:
# Harga    0
# dtype: int64

# %% [markdown]
# Normalisasi data dengan MinMaxScaler

# %%
scaler = MinMaxScaler() # inisialisasi MinMaxScaler untuk normalisasi data
scaled_data = scaler.fit_transform(df[['Harga']]) # normalisasi data harga daging sapi

# %%
print('Data setelah normalisasi:') # menampilkan data setelah normalisasi
scaled_df = pd.DataFrame(scaled_data, index=df.index, columns=['Harga_Daging_Sapi']) # membuat DataFrame baru dengan data yang sudah dinormalisasi
scaled_df.head() # menampilkan 5 baris pertama dari data yang sudah dinormalisasi
# Out:
# Data setelah normalisasi:
#             Harga_Daging_Sapi
# Tanggal
# 2018-01-02           0.225825
# 2018-01-03           0.275622
# 2018-01-04           0.060220
# 2018-01-05           0.218877
# 2018-01-08           0.214244

# %% [markdown]
# ## Membuat Fitur dan Target Menggunakan Sliding Window

# %%
def create_dataset(dataset, time_step=30): # fungsi untuk membuat dataset dengan time step 30
    X, y = [], [] # inisialisasi list untuk fitur (X) dan target (y)
    for i in range(len(dataset) - time_step): # iterasi untuk membuat fitur dan target
        X.append(dataset[i:(i + time_step), 0]) # mengambil data dari indeks i sampai i + time_step
        y.append(dataset[i + time_step, 0]) # target adalah data pada indeks i + time_step
    return np.array(X), np.array(y) # mengembalikan fitur dan target sebagai array numpy
time_step = 30 # mendefinisikan time step untuk dataset
X, y = create_dataset(scaled_data, time_step) # membuat dataset dengan time step 30
X = X.reshape(X.shape[0], X.shape[1], 1) # mengubah bentuk X menjadi 3D array untuk LSTM input

# %% [markdown]
# # Membangun Model LSTM

# %% [markdown]
# Membagi Rasio Data Latih dan Uji

# %%
train_size = int(len(X) * 0.8) # mendefinisikan ukuran data latih sebagai 80% dari total data
X_train, X_test = X[:train_size], X[train_size:] # membagi data menjadi data latih dan data uji
y_train, y_test = y[:train_size], y[train_size:] # membagi target menjadi data latih dan data uji

# %% [markdown]
# Membangun Hidden Layer LSTM

# %%
model = Sequential() # inisialisasi model Sequential
model.add(LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], 1))) # menambahkan layer LSTM pertama dengan 128 unit dan return_sequences=True
model.add(Dropout(0.2)) # menambahkan layer Dropout untuk mengurangi overfitting
model.add(LSTM(128)) # menambahkan layer LSTM kedua dengan 128 unit
model.add(Dropout(0.2)) # menambahkan layer Dropout kedua
model.add(Dense(1)) # menambahkan layer Dense output dengan 1 unit
optimizer = Adam(learning_rate=0.05) # inisialisasi optimizer Adam dengan learning rate 0.05
model.compile(optimizer=optimizer, loss='mean_squared_error') # mengkompilasi model dengan loss function mean squared error
# Out:
# c:\Users\mfasa\Documents\Ngoding\Deep Learning\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Training Model

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1) # melatih model dengan data latih dan validasi, selama 100 epoch dengan batch size 32
# Out:
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 6.7175 - val_loss: 0.1360
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1086 - val_loss: 0.0332
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0206 - val_loss: 0.0131
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0101 - val_loss: 0.0080
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0092 - val_loss: 0.0048
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0079 - val_loss: 0.0079
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0085 - val_loss: 0.0020
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0062 - val_loss: 0.0042
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0060 - val_loss: 0.0149
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0061 - val_loss: 0.0051
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 13/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0050 - val_loss: 0.0118
# Epoch 14/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0050 - val_loss: 0.0016
# Epoch 15/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0056 - val_loss: 0.0079
# Epoch 16/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0050 - val_loss: 0.0054
# Epoch 17/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0051 - val_loss: 0.0090
# Epoch 18/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 19/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 20/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0057 - val_loss: 0.0117
# Epoch 21/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0063 - val_loss: 0.0019
# Epoch 22/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0071 - val_loss: 0.0062
# Epoch 23/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0064 - val_loss: 0.0046
# Epoch 24/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0052 - val_loss: 0.0027
# Epoch 25/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0047 - val_loss: 0.0082
# Epoch 26/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 27/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0047 - val_loss: 0.0016
# Epoch 28/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 29/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0045 - val_loss: 0.0026
# Epoch 30/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 31/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 32/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0058 - val_loss: 0.0015
# Epoch 33/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0046 - val_loss: 0.0061
# Epoch 34/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 35/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 36/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0062 - val_loss: 0.0037
# Epoch 37/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0048 - val_loss: 0.0016
# Epoch 38/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 39/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 40/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 41/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 42/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0046 - val_loss: 0.0058
# Epoch 43/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0063 - val_loss: 0.0023
# Epoch 44/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0078 - val_loss: 0.0199
# Epoch 45/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0048 - val_loss: 0.0019
# Epoch 46/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0052 - val_loss: 0.0055
# Epoch 47/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0059 - val_loss: 0.0033
# Epoch 48/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0077 - val_loss: 0.0019
# Epoch 49/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0046 - val_loss: 0.0062
# Epoch 50/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 51/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0094 - val_loss: 0.0023
# Epoch 52/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0047 - val_loss: 0.0101
# Epoch 53/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 54/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 55/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 56/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0044 - val_loss: 0.0052
# Epoch 57/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0055 - val_loss: 0.0018
# Epoch 58/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0052 - val_loss: 0.0056
# Epoch 59/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0079 - val_loss: 0.0048
# Epoch 60/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0062 - val_loss: 0.0128
# Epoch 61/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 62/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0058 - val_loss: 0.0028
# Epoch 63/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0043 - val_loss: 0.0060
# Epoch 64/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 65/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 66/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0051 - val_loss: 0.0094
# Epoch 67/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0052 - val_loss: 0.0089
# Epoch 68/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0046 - val_loss: 0.0033
# Epoch 69/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0051 - val_loss: 0.0116
# Epoch 70/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0059 - val_loss: 0.0066
# Epoch 71/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0048 - val_loss: 0.0077
# Epoch 72/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0048 - val_loss: 0.0113
# Epoch 73/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0066 - val_loss: 0.0019
# Epoch 74/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0084 - val_loss: 0.0137
# Epoch 75/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0051 - val_loss: 0.0023
# Epoch 76/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 77/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0058 - val_loss: 0.0022
# Epoch 78/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0046 - val_loss: 0.0016
# Epoch 79/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 80/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0066 - val_loss: 0.0937
# Epoch 81/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0273 - val_loss: 0.0014
# Epoch 82/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0193 - val_loss: 0.0044
# Epoch 83/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0232 - val_loss: 0.0396
# Epoch 84/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0399 - val_loss: 0.0633
# Epoch 85/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0229 - val_loss: 0.0322
# Epoch 86/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0147 - val_loss: 0.0036
# Epoch 87/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0102 - val_loss: 0.0249
# Epoch 88/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0120 - val_loss: 0.0085
# Epoch 89/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0092 - val_loss: 0.0118
# Epoch 90/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0091 - val_loss: 0.0381
# Epoch 91/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0118 - val_loss: 0.0100
# Epoch 92/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0098 - val_loss: 0.0145
# Epoch 93/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0082 - val_loss: 0.0146
# Epoch 94/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0094 - val_loss: 0.0016
# Epoch 95/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0094 - val_loss: 0.0246
# Epoch 96/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0095 - val_loss: 0.0026
# Epoch 97/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0094 - val_loss: 0.0082
# Epoch 98/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0095 - val_loss: 0.0148
# Epoch 99/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0080 - val_loss: 0.0146
# Epoch 100/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0087 - val_loss: 0.0020

# %%
train_predict = model.predict(X_train) # melakukan prediksi pada data latih
test_predict = model.predict(X_test) # melakukan prediksi pada data uji
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# # Visualisasi Hasil Training

# %%
train_predict = scaler.inverse_transform(train_predict) # mengembalikan skala prediksi data latih
test_predict = scaler.inverse_transform(test_predict) # mengembalikan skala prediksi data uji
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1)) # mengembalikan skala target data latih
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1)) # mengembalikan skala target data uji

# %%
train_dates = df.index[time_step:train_size + time_step] # menagmbil tanggal untuk data latih
test_dates = df.index[train_size + time_step:] # mengambil tanggal untuk data uji

plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(train_dates, y_train_inv, label='Data Training Asli') # plot data asli training
plt.plot(train_dates, train_predict, label='Prediksi Training') # plot prediksi training
plt.plot(test_dates, y_test_inv, label='Data Testing Asli') # plot data asli testing
plt.plot(test_dates, test_predict, label='Prediksi Testing') # plot prediksi testing
plt.legend() # menampilkan legenda
plt.title('Prediksi Harga Daging Sapi dengan LSTM') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik prediksi harga daging sapi

# %% [markdown]
# # Evaluasi Model

# %%
# Hitung MSE
mse = mean_squared_error(y_test_inv, test_predict) # Hitung Mean Squared Error (MSE)
print(f'Mean Squared Error (MSE): {mse}') # menampilkan MSE

# Hitung RMSE
rmse = np.sqrt(mse) # Hitung Root Mean Squared Error (RMSE)
print(f'Root Mean Squared Error (RMSE): {rmse}') # menampilkan RMSE

# Hitung MAE
mae = mean_absolute_error(y_test_inv, test_predict) # Hitung Mean Absolute Error (MAE)
print(f'Mean Absolute Error (MAE): {mae}') # menampilkan MAE

# Hitung MAPE
mape = np.mean(np.abs((y_test_inv - test_predict) / (y_test_inv + 1e-8))) * 100 # Hitung Mean Absolute Percentage Error (MAPE) dan menghindari pembagian dengan nol
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%') # menampilkan MAPE
# Out:
# Mean Squared Error (MSE): 14549377.829432057
# Root Mean Squared Error (RMSE): 3814.3646691725817
# Mean Absolute Error (MAE): 2894.442860704787
# Mean Absolute Percentage Error (MAPE): 1.83%

# %% [markdown]
# # Prediksi 90 Hari Kedepan

# %% [markdown]
# Prediksi 90 hari ke depan (normalized)

# %%
future_steps = 90 # menentukan jumlah langkah prediksi ke depan
last_input = scaled_data[-time_step:].reshape(1, time_step, 1) # mengambil data terakhir untuk prediksi dan mengubah bentuknya menjadi 3D array
future_preds_90_norm = [] # inisialisasi list untuk menyimpan prediksi 90 hari ke depan

for _ in range(future_steps): # loop untuk melakukan prediksi 90 hari ke depan
    pred = model.predict(last_input, verbose=0) # melakukan prediksi dengan model
    future_preds_90_norm.append(pred[0, 0])  # menyimpan prediksi ke dalam list
    last_input = np.append(last_input[:, 1:, :], [[[pred[0, 0]]]], axis=1) # memperbarui input terakhir dengan prediksi baru

# %% [markdown]
# Denormalisasi hasil prediksi

# %%
future_preds_90_actual = scaler.inverse_transform(np.array(future_preds_90_norm).reshape(-1, 1)).flatten().astype(int) # denormalisasi hasil prediksi dan mengubahnya menjadi integer

# %% [markdown]
# Buat DataFrame untuk Tabel

# %%
last_date = df.index[-1] # mengambil tanggal terakhir dari data historis
future_dates_90 = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=future_steps) # membuat rentang tanggal untuk 90 hari ke depan

# Versi Normalized
df_future_90_norm = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga dinormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Normalized)': np.round(future_preds_90_norm, 6)
})

# Versi DENORMALIZED
df_future_90_actual = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga denormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Rp/Kg)': future_preds_90_actual
})

# Versi untuk plot/gabung (pakai index datetime)
df_future_90_plot = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan index datetime
    'Tanggal': future_dates_90,
    'Prediksi Harga Daging Sapi': future_preds_90_actual
}).set_index('Tanggal')

# %% [markdown]
# Gabungkan dengan data historis

# %%
df_all = pd.concat([ # menggabungkan DataFrame historis dengan prediksi 90 hari ke depan
    df[['Harga']], # mengambil kolom 'Harga_Daging_Sapi' dari DataFrame historis
    df_future_90_plot.rename(columns={'Prediksi Harga Daging Sapi': 'Harga'}) # mengganti nama kolom untuk konsistensi
])

# %% [markdown]
# Tampilkan tabel versi normalisasi dan denormalisasi

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Normalisasi):")
print(df_future_90_norm.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Normalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Normalized)
#   1 2025-05-31                                 0.616773
#   2 2025-06-01                                 0.616773
#   3 2025-06-02                                 0.616773
#   4 2025-06-03                                 0.513385
#   5 2025-06-04                                 0.616773
#   6 2025-06-05                                 0.616773
#   7 2025-06-06                                 0.616773
#   8 2025-06-07                                 0.616773
#   9 2025-06-08                                 0.616769
#  10 2025-06-09                                 0.616769
#  11 2025-06-10                                 0.616769
#  12 2025-06-11                                 0.616773
#  13 2025-06-12                                 0.616773
#  14 2025-06-13                                 0.616773
#  15 2025-06-14                                 0.616771
#  16 2025-06-15                                 0.616773
#  17 2025-06-16                                 0.616771
#  18 2025-06-17                                 0.616773
#  19 2025-06-18                                 0.616773
#  20 2025-06-19                                 0.616773
#  21 2025-06-20                                 0.616773
#  22 2025-06-21                                 0.616773
#  23 2025-06-22                                 0.616773
#  24 2025-06-23                                 0.616773
#  25 2025-06-24                                 0.616773
#  26 2025-06-25                                 0.616773
#  27 2025-06-26                                 0.616773
#  28 2025-06-27                                 0.616773
#  29 2025-06-28                                 0.616773
#  30 2025-06-29                                 0.616773
#  31 2025-06-30                                 0.616772
#  32 2025-07-01                                 0.616772
#  33 2025-07-02                                 0.616772
#  34 2025-07-03                                 0.615331
#  35 2025-07-04                                 0.616772
#  36 2025-07-05                                 0.616772
#  37 2025-07-06                                 0.616772
#  38 2025-07-07                                 0.616772
#  39 2025-07-08                                 0.616772
#  40 2025-07-09                                 0.616772
#  41 2025-07-10                                 0.616772
#  42 2025-07-11                                 0.616772
#  43 2025-07-12                                 0.616772
#  44 2025-07-13                                 0.616772
#  45 2025-07-14                                 0.616772
#  46 2025-07-15                                 0.616772
#  47 2025-07-16                                 0.616772
#  48 2025-07-17                                 0.616772
#  49 2025-07-18                                 0.616772
#  50 2025-07-19                                 0.616772
#  51 2025-07-20                                 0.616772
#  52 2025-07-21                                 0.616772
#  53 2025-07-22                                 0.616772
#  54 2025-07-23                                 0.616772
#  55 2025-07-24                                 0.616772
#  56 2025-07-25                                 0.616772
#  57 2025-07-26                                 0.616772
#  58 2025-07-27                                 0.616772
#  59 2025-07-28                                 0.616772
#  60 2025-07-29                                 0.616772
#  61 2025-07-30                                 0.616772
#  62 2025-07-31                                 0.616772
#  63 2025-08-01                                 0.616772
#  64 2025-08-02                                 0.616772
#  65 2025-08-03                                 0.616772
#  66 2025-08-04                                 0.616772
#  67 2025-08-05                                 0.616772
#  68 2025-08-06                                 0.616772
#  69 2025-08-07                                 0.616772
#  70 2025-08-08                                 0.616772
#  71 2025-08-09                                 0.616772
#  72 2025-08-10                                 0.616772
#  73 2025-08-11                                 0.616772
#  74 2025-08-12                                 0.616772
#  75 2025-08-13                                 0.616772
#  76 2025-08-14                                 0.616772
#  77 2025-08-15                                 0.616772
#  78 2025-08-16                                 0.616772
#  79 2025-08-17                                 0.616772
#  80 2025-08-18                                 0.616772
#  81 2025-08-19                                 0.616772
#  82 2025-08-20                                 0.616772
#  83 2025-08-21                                 0.616772
#  84 2025-08-22                                 0.616772
#  85 2025-08-23                                 0.616772
#  86 2025-08-24                                 0.616772
#  87 2025-08-25                                 0.616772
#  88 2025-08-26                                 0.616772
#  89 2025-08-27                                 0.616772
#  90 2025-08-28                                 0.616772

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Denormalisasi):")
print(df_future_90_actual.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Denormalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Rp/Kg)
#   1 2025-05-31                              155908
#   2 2025-06-01                              155908
#   3 2025-06-02                              155908
#   4 2025-06-03                              146980
#   5 2025-06-04                              155908
#   6 2025-06-05                              155908
#   7 2025-06-06                              155908
#   8 2025-06-07                              155908
#   9 2025-06-08                              155907
#  10 2025-06-09                              155907
#  11 2025-06-10                              155907
#  12 2025-06-11                              155908
#  13 2025-06-12                              155908
#  14 2025-06-13                              155908
#  15 2025-06-14                              155908
#  16 2025-06-15                              155908
#  17 2025-06-16                              155908
#  18 2025-06-17                              155908
#  19 2025-06-18                              155908
#  20 2025-06-19                              155908
#  21 2025-06-20                              155908
#  22 2025-06-21                              155908
#  23 2025-06-22                              155908
#  24 2025-06-23                              155908
#  25 2025-06-24                              155908
#  26 2025-06-25                              155908
#  27 2025-06-26                              155908
#  28 2025-06-27                              155908
#  29 2025-06-28                              155908
#  30 2025-06-29                              155908
#  31 2025-06-30                              155908
#  32 2025-07-01                              155908
#  33 2025-07-02                              155908
#  34 2025-07-03                              155783
#  35 2025-07-04                              155908
#  36 2025-07-05                              155908
#  37 2025-07-06                              155908
#  38 2025-07-07                              155908
#  39 2025-07-08                              155908
#  40 2025-07-09                              155908
#  41 2025-07-10                              155908
#  42 2025-07-11                              155908
#  43 2025-07-12                              155908
#  44 2025-07-13                              155908
#  45 2025-07-14                              155908
#  46 2025-07-15                              155908
#  47 2025-07-16                              155908
#  48 2025-07-17                              155908
#  49 2025-07-18                              155908
#  50 2025-07-19                              155908
#  51 2025-07-20                              155908
#  52 2025-07-21                              155908
#  53 2025-07-22                              155908
#  54 2025-07-23                              155908
#  55 2025-07-24                              155908
#  56 2025-07-25                              155908
#  57 2025-07-26                              155908
#  58 2025-07-27                              155908
#  59 2025-07-28                              155908
#  60 2025-07-29                              155908
#  61 2025-07-30                              155908
#  62 2025-07-31                              155908
#  63 2025-08-01                              155908
#  64 2025-08-02                              155908
#  65 2025-08-03                              155908
#  66 2025-08-04                              155908
#  67 2025-08-05                              155908
#  68 2025-08-06                              155908
#  69 2025-08-07                              155908
#  70 2025-08-08                              155908
#  71 2025-08-09                              155908
#  72 2025-08-10                              155908
#  73 2025-08-11                              155908
#  74 2025-08-12                              155908
#  75 2025-08-13                              155908
#  76 2025-08-14                              155908
#  77 2025-08-15                              155908
#  78 2025-08-16                              155908
#  79 2025-08-17                              155908
#  80 2025-08-18                              155908
#  81 2025-08-19                              155908
#  82 2025-08-20                              155908
#  83 2025-08-21                              155908
#  84 2025-08-22                              155908
#  85 2025-08-23                              155908
#  86 2025-08-24                              155908
#  87 2025-08-25                              155908
#  88 2025-08-26                              155908
#  89 2025-08-27                              155908
#  90 2025-08-28                              155908

# %% [markdown]
# Tampilkan plot harga historis 90 hari + prediksi 90 hari ke depan

# %%
window_hist = 90 # menentukan jumlah hari historis yang akan ditampilkan
last_hist_dates = df.index[-window_hist:] # mengambil tanggal historis terakhir
last_hist_prices = df['Harga'].iloc[-window_hist:] # mengambil harga historis terakhir

future_dates_90_plot = df_future_90_plot.index # mengambil tanggal untuk prediksi 90 hari ke depan
future_prices_90_plot = df_future_90_plot['Prediksi Harga Daging Sapi'] # mengambil harga prediksi 90 hari ke depan

plt.figure(figsize=(14,7)) # plot ukuran grafik
plt.plot(last_hist_dates, last_hist_prices, label=f'Harga Asli {window_hist} Hari Terakhir', color='blue') # plot harga historis terakhir
plt.plot(future_dates_90_plot, future_prices_90_plot, label='Prediksi 90 Hari Kedepan', color='orange', linestyle='--') # plot prediksi 90 hari ke depan
plt.axvline(x=last_hist_dates[-1], color='grey', linestyle=':', label='Batas Data Historis') # garis vertikal untuk batas data historis
plt.title(f'Harga Daging Sapi: {window_hist} Hari Terakhir & Prediksi 90 Hari Kedepan') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.xticks(rotation=45) # rotasi label sumbu x agar lebih mudah dibaca
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi dengan prediksi 90 hari ke depan

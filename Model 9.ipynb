# %% [markdown]
# # Import Package Yang Dibutuhkan

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %% [markdown]
# # Ambil dan Baca File Dataset

# %%
df = pd.read_csv("DATASET/dataset rata-rata.csv", sep=';') # membaca dataset dari file CSV dengan pemisah titik koma
df['Tanggal'] = pd.to_datetime(df['Tanggal'], dayfirst=True) # ubah kolom 'Tanggal' menjadi tipe datetime dan mengatur format hari-bulan-tahun
df = df.sort_values('Tanggal') # urutkan data berdasarkan tanggal
df.set_index('Tanggal', inplace=True) # set kolom 'Tanggal' sebagai index

# %%
df.head() # menampilkan 5 baris pertama dari dataset
# Out:
#                Harga
# Tanggal
# 2018-01-02  122150.0
# 2018-01-03  126450.0
# 2018-01-04  107850.0
# 2018-01-05  121550.0
# 2018-01-08  121150.0

# %%
df.tail() # menampilkan 5 baris terakhir dari dataset
# Out:
#                Harga
# Tanggal
# 2025-05-26  156100.0
# 2025-05-27  156100.0
# 2025-05-28  156100.0
# 2025-05-29  156100.0
# 2025-05-30  156100.0

# %%
plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(df.index, df['Harga'], label='Harga') # plot harga daging sapi
plt.title('Harga Daging Sapi 2018-2025') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi

# %%
print(df['Harga'].describe())
# Out:
# count      1908.000000
# mean     141551.808176
# std       13421.208265
# min      102650.000000
# 25%      131350.000000
# 50%      135150.000000
# 75%      156650.000000
# max      189000.000000
# Name: Harga, dtype: float64

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Pengecekan Nilai Kosong

# %%
print('Jumlah nilai kosong:') # menampilkan jumlah nilai kosong
df.isnull().sum() # menampilkan jumlah nilai kosong pada setiap kolom
# Out:
# Jumlah nilai kosong:
# Harga    14
# dtype: int64

# %% [markdown]
# Pengecekan Nilai Duplikat

# %%
duplicate_dates = df.index.duplicated().sum() # menghitung jumlah tanggal duplikat pada index
print(f'Jumlah tanggal duplikat pada index: {duplicate_dates}') # menampilkan jumlah tanggal duplikat pada index
# Out:
# Jumlah tanggal duplikat pada index: 0

# %% [markdown]
# Penghapusan Nilai Kosong

# %%
df = df.dropna() # menghapus baris yang memiliki nilai kosong

# %%
df.isnull().sum() # menampilkan jumlah nilai kosong setelah penghapusan
# Out:
# Harga    0
# dtype: int64

# %% [markdown]
# Normalisasi data dengan MinMaxScaler

# %%
scaler = MinMaxScaler() # inisialisasi MinMaxScaler untuk normalisasi data
scaled_data = scaler.fit_transform(df[['Harga']]) # normalisasi data harga daging sapi

# %%
print('Data setelah normalisasi:') # menampilkan data setelah normalisasi
scaled_df = pd.DataFrame(scaled_data, index=df.index, columns=['Harga_Daging_Sapi']) # membuat DataFrame baru dengan data yang sudah dinormalisasi
scaled_df.head() # menampilkan 5 baris pertama dari data yang sudah dinormalisasi
# Out:
# Data setelah normalisasi:
#             Harga_Daging_Sapi
# Tanggal
# 2018-01-02           0.225825
# 2018-01-03           0.275622
# 2018-01-04           0.060220
# 2018-01-05           0.218877
# 2018-01-08           0.214244

# %% [markdown]
# ## Membuat Fitur dan Target Menggunakan Sliding Window

# %%
def create_dataset(dataset, time_step=30): # fungsi untuk membuat dataset dengan time step 30
    X, y = [], [] # inisialisasi list untuk fitur (X) dan target (y)
    for i in range(len(dataset) - time_step): # iterasi untuk membuat fitur dan target
        X.append(dataset[i:(i + time_step), 0]) # mengambil data dari indeks i sampai i + time_step
        y.append(dataset[i + time_step, 0]) # target adalah data pada indeks i + time_step
    return np.array(X), np.array(y) # mengembalikan fitur dan target sebagai array numpy
time_step = 30 # mendefinisikan time step untuk dataset
X, y = create_dataset(scaled_data, time_step) # membuat dataset dengan time step 30
X = X.reshape(X.shape[0], X.shape[1], 1) # mengubah bentuk X menjadi 3D array untuk LSTM input

# %% [markdown]
# # Membangun Model LSTM

# %% [markdown]
# Membagi Rasio Data Latih dan Uji

# %%
train_size = int(len(X) * 0.7) # mendefinisikan ukuran data latih sebagai 70% dari total data
X_train, X_test = X[:train_size], X[train_size:] # membagi data menjadi data latih dan data uji
y_train, y_test = y[:train_size], y[train_size:] # membagi target menjadi data latih dan data uji

# %% [markdown]
# Membangun Hidden Layer LSTM

# %%
model = Sequential() # inisialisasi model Sequential
model.add(LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], 1))) # menambahkan layer LSTM pertama dengan 64 unit dan return_sequences=True
model.add(Dropout(0.2)) # menambahkan layer Dropout untuk mengurangi overfitting
model.add(LSTM(64)) # menambahkan layer LSTM kedua dengan 64 unit
model.add(Dropout(0.2)) # menambahkan layer Dropout kedua
model.add(Dense(1)) # menambahkan layer Dense output dengan 1 unit
optimizer = Adam(learning_rate=0.05) # inisialisasi optimizer Adam dengan learning rate 0.05
model.compile(optimizer=optimizer, loss='mean_squared_error') # mengkompilasi model dengan loss function mean squared error
# Out:
# c:\Users\mfasa\Documents\Ngoding\Deep Learning\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Training Model

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1) # melatih model dengan data latih dan validasi, selama 100 epoch dengan batch size 32
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 1.5941 - val_loss: 0.1069
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2622 - val_loss: 0.1031
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0139 - val_loss: 0.0024
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0074 - val_loss: 0.0030
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0081 - val_loss: 0.0036
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0041 - val_loss: 0.0088
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0040 - val_loss: 0.0138
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0092 - val_loss: 0.0656
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0121 - val_loss: 0.0708
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0123 - val_loss: 0.0725
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0118 - val_loss: 0.0761
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0117 - val_loss: 0.0683
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0106 - val_loss: 0.0371
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0113 - val_loss: 0.0063
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0139 - val_loss: 0.0631
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0117 - val_loss: 0.0649
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0120 - val_loss: 0.0739
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0122 - val_loss: 0.0865
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0121 - val_loss: 0.0698
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0115 - val_loss: 0.0659
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0114 - val_loss: 0.0682
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0123 - val_loss: 0.0786
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0121 - val_loss: 0.0710
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0115 - val_loss: 0.0743
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0112 - val_loss: 0.0743
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0116 - val_loss: 0.0724
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0114 - val_loss: 0.0760
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0113 - val_loss: 0.0706
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0121 - val_loss: 0.0824
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0124 - val_loss: 0.0670
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0125 - val_loss: 0.0748
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0113 - val_loss: 0.0692
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0118 - val_loss: 0.0646
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0111 - val_loss: 0.0954
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0236 - val_loss: 0.1770
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0273 - val_loss: 0.0049
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0223 - val_loss: 0.1036
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0135 - val_loss: 0.0669
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0121 - val_loss: 0.0909
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0123 - val_loss: 0.0576
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0120 - val_loss: 0.1018
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0156 - val_loss: 0.0543
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0136 - val_loss: 0.0793
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0107 - val_loss: 0.0473
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0129 - val_loss: 0.0605
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0115 - val_loss: 0.0596
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0107 - val_loss: 0.0606
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0104 - val_loss: 0.0477
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0090 - val_loss: 0.0401
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0083 - val_loss: 0.0288
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0100 - val_loss: 0.0402
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0061 - val_loss: 0.0124
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0081 - val_loss: 0.0791
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0132 - val_loss: 0.0409
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0142 - val_loss: 0.1070
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0121 - val_loss: 0.0739
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0131 - val_loss: 0.0679
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0120 - val_loss: 0.0834
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0122 - val_loss: 0.0773
# Epoch 62/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0121 - val_loss: 0.0615
# Epoch 63/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0125 - val_loss: 0.1014
# Epoch 64/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0138 - val_loss: 0.1019
# Epoch 65/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0130 - val_loss: 0.0665
# Epoch 66/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0124 - val_loss: 0.0923
# Epoch 67/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0134 - val_loss: 0.0765
# Epoch 68/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0113 - val_loss: 0.0633
# Epoch 69/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0115 - val_loss: 0.0921
# Epoch 70/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0131 - val_loss: 0.0790
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0127 - val_loss: 0.0683
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0120 - val_loss: 0.0797
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0116 - val_loss: 0.0559
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0121 - val_loss: 0.0826
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0118 - val_loss: 0.0614
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0123 - val_loss: 0.0726
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0117 - val_loss: 0.0676
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0124 - val_loss: 0.0895
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0121 - val_loss: 0.0533
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0131 - val_loss: 0.0447
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0130 - val_loss: 0.0723
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0108 - val_loss: 0.0455
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0083 - val_loss: 0.0309
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0066 - val_loss: 0.0034
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0231 - val_loss: 0.0223
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0110 - val_loss: 0.0483
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0135 - val_loss: 0.0722
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0114 - val_loss: 0.0711
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0113 - val_loss: 0.0795
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0120 - val_loss: 0.0918
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0121 - val_loss: 0.0720
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0120 - val_loss: 0.0834
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0121 - val_loss: 0.0819
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0125 - val_loss: 0.0719
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0122 - val_loss: 0.0624
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0121 - val_loss: 0.0693
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0110 - val_loss: 0.0678
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0122 - val_loss: 0.0787
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0117 - val_loss: 0.0605
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0126 - val_loss: 0.0780

# %%
train_predict = model.predict(X_train) # melakukan prediksi pada data latih
test_predict = model.predict(X_test) # melakukan prediksi pada data uji
# Out:
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# # Visualisasi Hasil Training

# %%
train_predict = scaler.inverse_transform(train_predict) # mengembalikan skala prediksi data latih
test_predict = scaler.inverse_transform(test_predict) # mengembalikan skala prediksi data uji
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1)) # mengembalikan skala target data latih
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1)) # mengembalikan skala target data uji

# %%
train_dates = df.index[time_step:train_size + time_step] # menagmbil tanggal untuk data latih
test_dates = df.index[train_size + time_step:] # mengambil tanggal untuk data uji

plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(train_dates, y_train_inv, label='Data Training Asli') # plot data asli training
plt.plot(train_dates, train_predict, label='Prediksi Training') # plot prediksi training
plt.plot(test_dates, y_test_inv, label='Data Testing Asli') # plot data asli testing
plt.plot(test_dates, test_predict, label='Prediksi Testing') # plot prediksi testing
plt.legend() # menampilkan legenda
plt.title('Prediksi Harga Daging Sapi dengan LSTM') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik prediksi harga daging sapi

# %% [markdown]
# # Evaluasi Model

# %%
# Hitung MSE
mse = mean_squared_error(y_test_inv, test_predict) # Hitung Mean Squared Error (MSE)
print(f'Mean Squared Error (MSE): {mse}') # menampilkan MSE

# Hitung RMSE
rmse = np.sqrt(mse) # Hitung Root Mean Squared Error (RMSE)
print(f'Root Mean Squared Error (RMSE): {rmse}') # menampilkan RMSE

# Hitung MAE
mae = mean_absolute_error(y_test_inv, test_predict) # Hitung Mean Absolute Error (MAE)
print(f'Mean Absolute Error (MAE): {mae}') # menampilkan MAE

# Hitung MAPE
mape = np.mean(np.abs((y_test_inv - test_predict) / (y_test_inv + 1e-8))) * 100 # Hitung Mean Absolute Percentage Error (MAPE) dan menghindari pembagian dengan nol
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%') # menampilkan MAPE
# Out:
# Mean Squared Error (MSE): 581282042.7419516
# Root Mean Squared Error (RMSE): 24109.79142883554
# Mean Absolute Error (MAE): 23742.1640902039
# Mean Absolute Percentage Error (MAPE): 14.98%

# %% [markdown]
# # Prediksi 90 Hari Kedepan

# %% [markdown]
# Prediksi 90 hari ke depan (normalized)

# %%
future_steps = 90 # menentukan jumlah langkah prediksi ke depan
last_input = scaled_data[-time_step:].reshape(1, time_step, 1) # mengambil data terakhir untuk prediksi dan mengubah bentuknya menjadi 3D array
future_preds_90_norm = [] # inisialisasi list untuk menyimpan prediksi 90 hari ke depan

for _ in range(future_steps): # loop untuk melakukan prediksi 90 hari ke depan
    pred = model.predict(last_input, verbose=0) # melakukan prediksi dengan model
    future_preds_90_norm.append(pred[0, 0])  # menyimpan prediksi ke dalam list
    last_input = np.append(last_input[:, 1:, :], [[[pred[0, 0]]]], axis=1) # memperbarui input terakhir dengan prediksi baru

# %% [markdown]
# Denormalisasi hasil prediksi

# %%
future_preds_90_actual = scaler.inverse_transform(np.array(future_preds_90_norm).reshape(-1, 1)).flatten().astype(int) # denormalisasi hasil prediksi dan mengubahnya menjadi integer

# %% [markdown]
# Buat DataFrame untuk Tabel

# %%
last_date = df.index[-1] # mengambil tanggal terakhir dari data historis
future_dates_90 = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=future_steps) # membuat rentang tanggal untuk 90 hari ke depan

# Versi Normalized
df_future_90_norm = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga dinormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Normalized)': np.round(future_preds_90_norm, 6)
})

# Versi DENORMALIZED
df_future_90_actual = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga denormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Rp/Kg)': future_preds_90_actual
})

# Versi untuk plot/gabung (pakai index datetime)
df_future_90_plot = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan index datetime
    'Tanggal': future_dates_90,
    'Prediksi Harga Daging Sapi': future_preds_90_actual
}).set_index('Tanggal')

# %% [markdown]
# Gabungkan dengan data historis

# %%
df_all = pd.concat([ # menggabungkan DataFrame historis dengan prediksi 90 hari ke depan
    df[['Harga']], # mengambil kolom 'Harga_Daging_Sapi' dari DataFrame historis
    df_future_90_plot.rename(columns={'Prediksi Harga Daging Sapi': 'Harga'}) # mengganti nama kolom untuk konsistensi
])

# %% [markdown]
# Tampilkan tabel versi normalisasi dan denormalisasi

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Normalisasi):")
print(df_future_90_norm.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Normalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Normalized)
#   1 2025-05-31                                 0.364290
#   2 2025-06-01                                 0.364110
#   3 2025-06-02                                 0.364188
#   4 2025-06-03                                 0.364123
#   5 2025-06-04                                 0.364173
#   6 2025-06-05                                 0.364166
#   7 2025-06-06                                 0.364157
#   8 2025-06-07                                 0.364148
#   9 2025-06-08                                 0.364136
#  10 2025-06-09                                 0.364133
#  11 2025-06-10                                 0.364128
#  12 2025-06-11                                 0.364125
#  13 2025-06-12                                 0.364118
#  14 2025-06-13                                 0.364111
#  15 2025-06-14                                 0.364101
#  16 2025-06-15                                 0.364097
#  17 2025-06-16                                 0.364089
#  18 2025-06-17                                 0.364084
#  19 2025-06-18                                 0.364079
#  20 2025-06-19                                 0.364077
#  21 2025-06-20                                 0.364076
#  22 2025-06-21                                 0.364075
#  23 2025-06-22                                 0.364072
#  24 2025-06-23                                 0.364057
#  25 2025-06-24                                 0.364026
#  26 2025-06-25                                 0.363979
#  27 2025-06-26                                 0.363975
#  28 2025-06-27                                 0.363967
#  29 2025-06-28                                 0.363879
#  30 2025-06-29                                 0.363910
#  31 2025-06-30                                 0.363730
#  32 2025-07-01                                 0.363730
#  33 2025-07-02                                 0.363730
#  34 2025-07-03                                 0.363730
#  35 2025-07-04                                 0.363730
#  36 2025-07-05                                 0.363730
#  37 2025-07-06                                 0.363730
#  38 2025-07-07                                 0.363730
#  39 2025-07-08                                 0.363730
#  40 2025-07-09                                 0.363730
#  41 2025-07-10                                 0.363730
#  42 2025-07-11                                 0.363730
#  43 2025-07-12                                 0.363730
#  44 2025-07-13                                 0.363730
#  45 2025-07-14                                 0.363730
#  46 2025-07-15                                 0.363730
#  47 2025-07-16                                 0.363730
#  48 2025-07-17                                 0.363730
#  49 2025-07-18                                 0.363730
#  50 2025-07-19                                 0.363730
#  51 2025-07-20                                 0.363730
#  52 2025-07-21                                 0.363730
#  53 2025-07-22                                 0.363730
#  54 2025-07-23                                 0.363729
#  55 2025-07-24                                 0.363729
#  56 2025-07-25                                 0.363729
#  57 2025-07-26                                 0.363729
#  58 2025-07-27                                 0.363729
#  59 2025-07-28                                 0.363729
#  60 2025-07-29                                 0.363729
#  61 2025-07-30                                 0.363729
#  62 2025-07-31                                 0.363729
#  63 2025-08-01                                 0.363729
#  64 2025-08-02                                 0.363729
#  65 2025-08-03                                 0.363729
#  66 2025-08-04                                 0.363729
#  67 2025-08-05                                 0.363729
#  68 2025-08-06                                 0.363729
#  69 2025-08-07                                 0.363729
#  70 2025-08-08                                 0.363729
#  71 2025-08-09                                 0.363729
#  72 2025-08-10                                 0.363729
#  73 2025-08-11                                 0.363729
#  74 2025-08-12                                 0.363729
#  75 2025-08-13                                 0.363729
#  76 2025-08-14                                 0.363729
#  77 2025-08-15                                 0.363729
#  78 2025-08-16                                 0.363729
#  79 2025-08-17                                 0.363729
#  80 2025-08-18                                 0.363729
#  81 2025-08-19                                 0.363729
#  82 2025-08-20                                 0.363729
#  83 2025-08-21                                 0.363729
#  84 2025-08-22                                 0.363729
#  85 2025-08-23                                 0.363729
#  86 2025-08-24                                 0.363729
#  87 2025-08-25                                 0.363729
#  88 2025-08-26                                 0.363729
#  89 2025-08-27                                 0.363729
#  90 2025-08-28                                 0.363729

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Denormalisasi):")
print(df_future_90_actual.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Denormalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Rp/Kg)
#   1 2025-05-31                              134106
#   2 2025-06-01                              134090
#   3 2025-06-02                              134097
#   4 2025-06-03                              134092
#   5 2025-06-04                              134096
#   6 2025-06-05                              134095
#   7 2025-06-06                              134094
#   8 2025-06-07                              134094
#   9 2025-06-08                              134093
#  10 2025-06-09                              134092
#  11 2025-06-10                              134092
#  12 2025-06-11                              134092
#  13 2025-06-12                              134091
#  14 2025-06-13                              134090
#  15 2025-06-14                              134090
#  16 2025-06-15                              134089
#  17 2025-06-16                              134089
#  18 2025-06-17                              134088
#  19 2025-06-18                              134088
#  20 2025-06-19                              134088
#  21 2025-06-20                              134087
#  22 2025-06-21                              134087
#  23 2025-06-22                              134087
#  24 2025-06-23                              134086
#  25 2025-06-24                              134083
#  26 2025-06-25                              134079
#  27 2025-06-26                              134079
#  28 2025-06-27                              134078
#  29 2025-06-28                              134070
#  30 2025-06-29                              134073
#  31 2025-06-30                              134058
#  32 2025-07-01                              134058
#  33 2025-07-02                              134058
#  34 2025-07-03                              134058
#  35 2025-07-04                              134058
#  36 2025-07-05                              134058
#  37 2025-07-06                              134058
#  38 2025-07-07                              134058
#  39 2025-07-08                              134058
#  40 2025-07-09                              134058
#  41 2025-07-10                              134058
#  42 2025-07-11                              134058
#  43 2025-07-12                              134058
#  44 2025-07-13                              134058
#  45 2025-07-14                              134058
#  46 2025-07-15                              134058
#  47 2025-07-16                              134058
#  48 2025-07-17                              134058
#  49 2025-07-18                              134058
#  50 2025-07-19                              134058
#  51 2025-07-20                              134058
#  52 2025-07-21                              134058
#  53 2025-07-22                              134058
#  54 2025-07-23                              134058
#  55 2025-07-24                              134058
#  56 2025-07-25                              134058
#  57 2025-07-26                              134058
#  58 2025-07-27                              134058
#  59 2025-07-28                              134058
#  60 2025-07-29                              134058
#  61 2025-07-30                              134058
#  62 2025-07-31                              134058
#  63 2025-08-01                              134058
#  64 2025-08-02                              134058
#  65 2025-08-03                              134058
#  66 2025-08-04                              134058
#  67 2025-08-05                              134058
#  68 2025-08-06                              134058
#  69 2025-08-07                              134058
#  70 2025-08-08                              134058
#  71 2025-08-09                              134058
#  72 2025-08-10                              134058
#  73 2025-08-11                              134058
#  74 2025-08-12                              134058
#  75 2025-08-13                              134058
#  76 2025-08-14                              134058
#  77 2025-08-15                              134058
#  78 2025-08-16                              134058
#  79 2025-08-17                              134058
#  80 2025-08-18                              134058
#  81 2025-08-19                              134058
#  82 2025-08-20                              134058
#  83 2025-08-21                              134058
#  84 2025-08-22                              134058
#  85 2025-08-23                              134058
#  86 2025-08-24                              134058
#  87 2025-08-25                              134058
#  88 2025-08-26                              134058
#  89 2025-08-27                              134058
#  90 2025-08-28                              134058

# %% [markdown]
# Tampilkan plot harga historis 90 hari + prediksi 90 hari ke depan

# %%
window_hist = 90 # menentukan jumlah hari historis yang akan ditampilkan
last_hist_dates = df.index[-window_hist:] # mengambil tanggal historis terakhir
last_hist_prices = df['Harga'].iloc[-window_hist:] # mengambil harga historis terakhir

future_dates_90_plot = df_future_90_plot.index # mengambil tanggal untuk prediksi 90 hari ke depan
future_prices_90_plot = df_future_90_plot['Prediksi Harga Daging Sapi'] # mengambil harga prediksi 90 hari ke depan

plt.figure(figsize=(14,7)) # plot ukuran grafik
plt.plot(last_hist_dates, last_hist_prices, label=f'Harga Asli {window_hist} Hari Terakhir', color='blue') # plot harga historis terakhir
plt.plot(future_dates_90_plot, future_prices_90_plot, label='Prediksi 90 Hari Kedepan', color='orange', linestyle='--') # plot prediksi 90 hari ke depan
plt.axvline(x=last_hist_dates[-1], color='grey', linestyle=':', label='Batas Data Historis') # garis vertikal untuk batas data historis
plt.title(f'Harga Daging Sapi: {window_hist} Hari Terakhir & Prediksi 90 Hari Kedepan') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.xticks(rotation=45) # rotasi label sumbu x agar lebih mudah dibaca
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi dengan prediksi 90 hari ke depan

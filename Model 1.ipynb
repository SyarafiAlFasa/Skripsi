# %% [markdown]
# # Import Package Yang Dibutuhkan

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %% [markdown]
# # Ambil dan Baca File Dataset

# %%
df = pd.read_csv("DATASET/dataset rata-rata.csv", sep=';') # membaca dataset dari file CSV dengan pemisah titik koma
df['Tanggal'] = pd.to_datetime(df['Tanggal'], dayfirst=True) # ubah kolom 'Tanggal' menjadi tipe datetime dan mengatur format hari-bulan-tahun
df = df.sort_values('Tanggal') # urutkan data berdasarkan tanggal
df.set_index('Tanggal', inplace=True) # set kolom 'Tanggal' sebagai index

# %%
df.head() # menampilkan 5 baris pertama dari dataset
# Out:
#                Harga
# Tanggal
# 2018-01-02  122150.0
# 2018-01-03  126450.0
# 2018-01-04  107850.0
# 2018-01-05  121550.0
# 2018-01-08  121150.0

# %%
df.tail() # menampilkan 5 baris terakhir dari dataset
# Out:
#                Harga
# Tanggal
# 2025-05-26  156100.0
# 2025-05-27  156100.0
# 2025-05-28  156100.0
# 2025-05-29  156100.0
# 2025-05-30  156100.0

# %%
plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(df.index, df['Harga'], label='Harga') # plot harga daging sapi
plt.title('Harga Daging Sapi 2018-2025') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi

# %%
print(df['Harga'].describe())
# Out:
# count      1908.000000
# mean     141551.808176
# std       13421.208265
# min      102650.000000
# 25%      131350.000000
# 50%      135150.000000
# 75%      156650.000000
# max      189000.000000
# Name: Harga, dtype: float64

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Pengecekan Nilai Kosong

# %%
print('Jumlah nilai kosong:') # menampilkan jumlah nilai kosong
df.isnull().sum() # menampilkan jumlah nilai kosong pada setiap kolom
# Out:
# Jumlah nilai kosong:
# Harga    14
# dtype: int64

# %% [markdown]
# Pengecekan Nilai Duplikat

# %%
duplicate_dates = df.index.duplicated().sum() # menghitung jumlah tanggal duplikat pada index
print(f'Jumlah tanggal duplikat pada index: {duplicate_dates}') # menampilkan jumlah tanggal duplikat pada index
# Out:
# Jumlah tanggal duplikat pada index: 0

# %% [markdown]
# Penghapusan Nilai Kosong

# %%
df = df.dropna() # menghapus baris yang memiliki nilai kosong

# %%
df.isnull().sum() # menampilkan jumlah nilai kosong setelah penghapusan
# Out:
# Harga    0
# dtype: int64

# %% [markdown]
# Normalisasi data dengan MinMaxScaler

# %%
scaler = MinMaxScaler() # inisialisasi MinMaxScaler untuk normalisasi data
scaled_data = scaler.fit_transform(df[['Harga']]) # normalisasi data harga daging sapi

# %%
print('Data setelah normalisasi:') # menampilkan data setelah normalisasi
scaled_df = pd.DataFrame(scaled_data, index=df.index, columns=['Harga_Daging_Sapi']) 
scaled_df.head() # menampilkan 5 baris pertama dari data yang sudah dinormalisasi
# Out:
# Data setelah normalisasi:
#             Harga_Daging_Sapi
# Tanggal
# 2018-01-02           0.225825
# 2018-01-03           0.275622
# 2018-01-04           0.060220
# 2018-01-05           0.218877
# 2018-01-08           0.214244

# %% [markdown]
# ## Membuat Fitur dan Target Menggunakan Sliding Window

# %%
def create_dataset(dataset, time_step=30): # fungsi untuk membuat dataset dengan time step 30
    X, y = [], [] # inisialisasi list untuk fitur (X) dan target (y)
    for i in range(len(dataset) - time_step): # iterasi untuk membuat fitur dan target
        X.append(dataset[i:(i + time_step), 0]) # mengambil data dari indeks i sampai i + time_step
        y.append(dataset[i + time_step, 0]) # target adalah data pada indeks i + time_step
    return np.array(X), np.array(y) # mengembalikan fitur dan target sebagai array numpy
time_step = 30 # mendefinisikan time step untuk dataset
X, y = create_dataset(scaled_data, time_step) # membuat dataset dengan time step 30
X = X.reshape(X.shape[0], X.shape[1], 1) # mengubah bentuk X menjadi 3D array untuk LSTM input

# %% [markdown]
# # Membangun Model LSTM

# %% [markdown]
# Membagi Rasio Data Latih dan Uji

# %%
train_size = int(len(X) * 0.7) # mendefinisikan ukuran data latih sebagai 70% dari total data
X_train, X_test = X[:train_size], X[train_size:] # membagi data menjadi data latih dan data uji
y_train, y_test = y[:train_size], y[train_size:] # membagi target menjadi data latih dan data uji

# %% [markdown]
# Membangun Hidden Layer LSTM

# %%
model = Sequential() # inisialisasi model Sequential
model.add(LSTM(20, return_sequences=True, input_shape=(X_train.shape[1], 1))) # menambahkan layer LSTM pertama dengan 20 unit dan return_sequences=True
model.add(Dropout(0.2)) # menambahkan layer Dropout untuk mengurangi overfitting
model.add(LSTM(20)) # menambahkan layer LSTM kedua dengan 20 unit
model.add(Dropout(0.2)) # menambahkan layer Dropout kedua
model.add(Dense(1)) # menambahkan layer Dense output dengan 1 unit
optimizer = Adam(learning_rate=0.001) # inisialisasi optimizer Adam dengan learning rate 0.001
model.compile(optimizer=optimizer, loss='mean_squared_error') # mengkompilasi model dengan loss function mean squared error
# Out:
# c:\Users\mfasa\Documents\Ngoding\Deep Learning\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Training Model

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0607 - val_loss: 0.0242
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0052 - val_loss: 0.0035
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0042 - val_loss: 0.0023
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0037 - val_loss: 0.0023
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0037 - val_loss: 0.0023
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 62/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 63/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 64/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 65/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 66/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 67/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 68/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 69/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 70/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 0.0021

# %%
train_predict = model.predict(X_train) # melakukan prediksi pada data latih
test_predict = model.predict(X_test) # melakukan prediksi pada data uji
# Out:
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# # Visualisasi Hasil Training

# %%
train_predict = scaler.inverse_transform(train_predict) # mengembalikan skala prediksi data latih
test_predict = scaler.inverse_transform(test_predict) # mengembalikan skala prediksi data uji
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1)) # mengembalikan skala target data latih
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1)) # mengembalikan skala target data uji

# %%
train_dates = df.index[time_step:train_size + time_step] # menagmbil tanggal untuk data latih
test_dates = df.index[train_size + time_step:] # mengambil tanggal untuk data uji

plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(train_dates, y_train_inv, label='Data Training Asli') # plot data asli training
plt.plot(train_dates, train_predict, label='Prediksi Training') # plot prediksi training
plt.plot(test_dates, y_test_inv, label='Data Testing Asli') # plot data asli testing
plt.plot(test_dates, test_predict, label='Prediksi Testing') # plot prediksi testing
plt.legend() # menampilkan legenda
plt.title('Prediksi Harga Daging Sapi dengan LSTM') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik prediksi harga daging sapi

# %%
print(f'Jumlah baris data latih: {len(X_train)}')
print(f'Jumlah baris data uji: {len(X_test)}')
# Out:
# Jumlah baris data latih: 1314
# Jumlah baris data uji: 564

# %%
# Buat DataFrame perbandingan harga aktual dan prediksi pada data uji
df_perbandingan_uji = pd.DataFrame({
    'Tanggal': test_dates,
    'Harga Aktual': y_test_inv.flatten(),
    'Harga Prediksi': test_predict.flatten()
}).set_index('Tanggal')

# Tambahkan kolom selisih absolut
df_perbandingan_uji['Selisih Absolut'] = np.abs(df_perbandingan_uji['Harga Aktual'] - df_perbandingan_uji['Harga Prediksi'])

print(df_perbandingan_uji.tail(20))  # tampilkan 20 baris terakhir

# Export ke Excel
with pd.ExcelWriter('perbandingan_harga_uji.xlsx') as writer:
    df_perbandingan_uji.to_excel(writer, sheet_name='Perbandingan_Uji')
# Out:
#             Harga Aktual  Harga Prediksi  Selisih Absolut
# Tanggal
# 2025-05-05      155000.0   154813.015625       186.984375
# 2025-05-06      156100.0   154900.390625      1199.609375
# 2025-05-07      156100.0   155055.265625      1044.734375
# 2025-05-08      156100.0   155226.312500       873.687500
# 2025-05-09      155650.0   155392.265625       257.734375
# 2025-05-12      156100.0   155501.109375       598.890625
# 2025-05-13      155650.0   155614.062500        35.937500
# 2025-05-14      156100.0   155679.500000       420.500000
# 2025-05-15      156100.0   155759.937500       340.062500
# 2025-05-16      156100.0   155838.453125       261.546875
# 2025-05-19      156100.0   155909.500000       190.500000
# 2025-05-20      156100.0   155971.468750       128.531250
# 2025-05-21      156100.0   156024.421875        75.578125
# 2025-05-22      156100.0   156069.968750        30.031250
# 2025-05-23      156100.0   156107.531250         7.531250
# 2025-05-26      156100.0   156138.734375        38.734375
# 2025-05-27      156100.0   156162.890625        62.890625
# 2025-05-28      156100.0   156182.546875        82.546875
# 2025-05-29      156100.0   156198.671875        98.671875
# 2025-05-30      156100.0   156211.890625       111.890625

# %% [markdown]
# # Evaluasi Model

# %%
# Hitung MSE
mse = mean_squared_error(y_test_inv, test_predict) # Hitung Mean Squared Error (MSE)
print(f'Mean Squared Error (MSE): {mse}') # menampilkan MSE

# Hitung RMSE
rmse = np.sqrt(mse) # Hitung Root Mean Squared Error (RMSE)
print(f'Root Mean Squared Error (RMSE): {rmse}') # menampilkan RMSE

# Hitung MAE
mae = mean_absolute_error(y_test_inv, test_predict) # Hitung Mean Absolute Error (MAE)
print(f'Mean Absolute Error (MAE): {mae}') # menampilkan MAE

# Hitung MAPE
mape = np.mean(np.abs((y_test_inv - test_predict) / (y_test_inv + 1e-8))) * 100 # Hitung Mean Absolute Percentage Error (MAPE)
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%') # menampilkan MAPE
# Out:
# Mean Squared Error (MSE): 15752316.267605392
# Root Mean Squared Error (RMSE): 3968.9187781567657
# Mean Absolute Error (MAE): 2218.821337544326
# Mean Absolute Percentage Error (MAPE): 1.42%

# %% [markdown]
# # Prediksi 90 Hari Kedepan

# %% [markdown]
# Prediksi 90 hari ke depan (normalized)

# %%
future_steps = 90 # menentukan jumlah langkah prediksi ke depan
last_input = scaled_data[-time_step:].reshape(1, time_step, 1) # mengambil data terakhir untuk prediksi dan mengubah bentuknya menjadi 3D array
future_preds_90_norm = [] # inisialisasi list untuk menyimpan prediksi 90 hari ke depan

for _ in range(future_steps): # loop untuk melakukan prediksi 90 hari ke depan
    pred = model.predict(last_input, verbose=0) # melakukan prediksi dengan model
    future_preds_90_norm.append(pred[0, 0])  # menyimpan prediksi ke dalam list
    last_input = np.append(last_input[:, 1:, :], [[[pred[0, 0]]]], axis=1) # memperbarui input terakhir dengan prediksi baru

# %% [markdown]
# Denormalisasi hasil prediksi

# %%
future_preds_90_actual = scaler.inverse_transform(np.array(future_preds_90_norm).reshape(-1, 1)).flatten().astype(int) # denormalisasi hasil prediksi dan mengubahnya menjadi integer

# %% [markdown]
# Buat DataFrame untuk Tabel

# %%
last_date = df.index[-1] # mengambil tanggal terakhir dari data historis
future_dates_90 = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=future_steps) # membuat rentang tanggal untuk 90 hari ke depan

# Versi Normalized
df_future_90_norm = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga dinormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Normalized)': np.round(future_preds_90_norm, 6)
})

# Versi DENORMALIZED
df_future_90_actual = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga denormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Rp/Kg)': future_preds_90_actual
})

# Versi untuk plot/gabung (pakai index datetime)
df_future_90_plot = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan index datetime
    'Tanggal': future_dates_90,
    'Prediksi Harga Daging Sapi': future_preds_90_actual
}).set_index('Tanggal')

# %% [markdown]
# Gabungkan dengan data historis

# %%
df_all = pd.concat([ # menggabungkan DataFrame historis dengan prediksi 90 hari ke depan
    df[['Harga']], # mengambil kolom 'Harga_Daging_Sapi' dari DataFrame historis
    df_future_90_plot.rename(columns={'Prediksi Harga Daging Sapi': 'Harga'}) # mengganti nama kolom untuk konsistensi
])

# %% [markdown]
# Tampilkan tabel versi normalisasi dan denormalisasi

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Normalisasi):")
print(df_future_90_norm.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Normalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Normalized)
#   1 2025-05-31                                 0.620414
#   2 2025-06-01                                 0.620638
#   3 2025-06-02                                 0.620909
#   4 2025-06-03                                 0.621204
#   5 2025-06-04                                 0.621577
#   6 2025-06-05                                 0.621879
#   7 2025-06-06                                 0.622189
#   8 2025-06-07                                 0.622504
#   9 2025-06-08                                 0.622821
#  10 2025-06-09                                 0.623144
#  11 2025-06-10                                 0.623466
#  12 2025-06-11                                 0.623790
#  13 2025-06-12                                 0.624109
#  14 2025-06-13                                 0.624430
#  15 2025-06-14                                 0.624753
#  16 2025-06-15                                 0.625079
#  17 2025-06-16                                 0.625404
#  18 2025-06-17                                 0.625733
#  19 2025-06-18                                 0.626061
#  20 2025-06-19                                 0.626391
#  21 2025-06-20                                 0.626722
#  22 2025-06-21                                 0.627055
#  23 2025-06-22                                 0.627390
#  24 2025-06-23                                 0.627726
#  25 2025-06-24                                 0.628064
#  26 2025-06-25                                 0.628403
#  27 2025-06-26                                 0.628744
#  28 2025-06-27                                 0.629086
#  29 2025-06-28                                 0.629430
#  30 2025-06-29                                 0.629775
#  31 2025-06-30                                 0.630121
#  32 2025-07-01                                 0.630469
#  33 2025-07-02                                 0.630818
#  34 2025-07-03                                 0.631169
#  35 2025-07-04                                 0.631521
#  36 2025-07-05                                 0.631874
#  37 2025-07-06                                 0.632229
#  38 2025-07-07                                 0.632586
#  39 2025-07-08                                 0.632944
#  40 2025-07-09                                 0.633303
#  41 2025-07-10                                 0.633664
#  42 2025-07-11                                 0.634027
#  43 2025-07-12                                 0.634391
#  44 2025-07-13                                 0.634756
#  45 2025-07-14                                 0.635123
#  46 2025-07-15                                 0.635492
#  47 2025-07-16                                 0.635862
#  48 2025-07-17                                 0.636234
#  49 2025-07-18                                 0.636607
#  50 2025-07-19                                 0.636982
#  51 2025-07-20                                 0.637358
#  52 2025-07-21                                 0.637736
#  53 2025-07-22                                 0.638116
#  54 2025-07-23                                 0.638497
#  55 2025-07-24                                 0.638880
#  56 2025-07-25                                 0.639264
#  57 2025-07-26                                 0.639650
#  58 2025-07-27                                 0.640038
#  59 2025-07-28                                 0.640427
#  60 2025-07-29                                 0.640818
#  61 2025-07-30                                 0.641211
#  62 2025-07-31                                 0.641605
#  63 2025-08-01                                 0.642001
#  64 2025-08-02                                 0.642399
#  65 2025-08-03                                 0.642798
#  66 2025-08-04                                 0.643199
#  67 2025-08-05                                 0.643602
#  68 2025-08-06                                 0.644006
#  69 2025-08-07                                 0.644412
#  70 2025-08-08                                 0.644820
#  71 2025-08-09                                 0.645230
#  72 2025-08-10                                 0.645641
#  73 2025-08-11                                 0.646054
#  74 2025-08-12                                 0.646470
#  75 2025-08-13                                 0.646886
#  76 2025-08-14                                 0.647305
#  77 2025-08-15                                 0.647725
#  78 2025-08-16                                 0.648147
#  79 2025-08-17                                 0.648571
#  80 2025-08-18                                 0.648997
#  81 2025-08-19                                 0.649424
#  82 2025-08-20                                 0.649854
#  83 2025-08-21                                 0.650285
#  84 2025-08-22                                 0.650718
#  85 2025-08-23                                 0.651153
#  86 2025-08-24                                 0.651590
#  87 2025-08-25                                 0.652029
#  88 2025-08-26                                 0.652470
#  89 2025-08-27                                 0.652912
#  90 2025-08-28                                 0.653357

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Denormalisasi):")
print(df_future_90_actual.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Denormalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Rp/Kg)
#   1 2025-05-31                              156222
#   2 2025-06-01                              156242
#   3 2025-06-02                              156265
#   4 2025-06-03                              156290
#   5 2025-06-04                              156323
#   6 2025-06-05                              156349
#   7 2025-06-06                              156376
#   8 2025-06-07                              156403
#   9 2025-06-08                              156430
#  10 2025-06-09                              156458
#  11 2025-06-10                              156486
#  12 2025-06-11                              156514
#  13 2025-06-12                              156541
#  14 2025-06-13                              156569
#  15 2025-06-14                              156597
#  16 2025-06-15                              156625
#  17 2025-06-16                              156653
#  18 2025-06-17                              156682
#  19 2025-06-18                              156710
#  20 2025-06-19                              156738
#  21 2025-06-20                              156767
#  22 2025-06-21                              156796
#  23 2025-06-22                              156825
#  24 2025-06-23                              156854
#  25 2025-06-24                              156883
#  26 2025-06-25                              156912
#  27 2025-06-26                              156942
#  28 2025-06-27                              156971
#  29 2025-06-28                              157001
#  30 2025-06-29                              157031
#  31 2025-06-30                              157060
#  32 2025-07-01                              157090
#  33 2025-07-02                              157121
#  34 2025-07-03                              157151
#  35 2025-07-04                              157181
#  36 2025-07-05                              157212
#  37 2025-07-06                              157243
#  38 2025-07-07                              157273
#  39 2025-07-08                              157304
#  40 2025-07-09                              157335
#  41 2025-07-10                              157366
#  42 2025-07-11                              157398
#  43 2025-07-12                              157429
#  44 2025-07-13                              157461
#  45 2025-07-14                              157492
#  46 2025-07-15                              157524
#  47 2025-07-16                              157556
#  48 2025-07-17                              157588
#  49 2025-07-18                              157621
#  50 2025-07-19                              157653
#  51 2025-07-20                              157685
#  52 2025-07-21                              157718
#  53 2025-07-22                              157751
#  54 2025-07-23                              157784
#  55 2025-07-24                              157817
#  56 2025-07-25                              157850
#  57 2025-07-26                              157883
#  58 2025-07-27                              157917
#  59 2025-07-28                              157950
#  60 2025-07-29                              157984
#  61 2025-07-30                              158018
#  62 2025-07-31                              158052
#  63 2025-08-01                              158086
#  64 2025-08-02                              158121
#  65 2025-08-03                              158155
#  66 2025-08-04                              158190
#  67 2025-08-05                              158225
#  68 2025-08-06                              158259
#  69 2025-08-07                              158295
#  70 2025-08-08                              158330
#  71 2025-08-09                              158365
#  72 2025-08-10                              158401
#  73 2025-08-11                              158436
#  74 2025-08-12                              158472
#  75 2025-08-13                              158508
#  76 2025-08-14                              158544
#  77 2025-08-15                              158581
#  78 2025-08-16                              158617
#  79 2025-08-17                              158654
#  80 2025-08-18                              158690
#  81 2025-08-19                              158727
#  82 2025-08-20                              158764
#  83 2025-08-21                              158802
#  84 2025-08-22                              158839
#  85 2025-08-23                              158877
#  86 2025-08-24                              158914
#  87 2025-08-25                              158952
#  88 2025-08-26                              158990
#  89 2025-08-27                              159028
#  90 2025-08-28                              159067

# %% [markdown]
# Tampilkan plot harga historis 90 hari + prediksi 90 hari ke depan

# %%
plt.figure(figsize=(12,6))
plt.plot(last_hist_dates, last_hist_prices, label='Harga Asli 90 Hari Terakhir')
plt.plot(future_dates_90_plot, future_preds_90_actual, label='Prediksi Harga 90 Hari Kedepan')
plt.title('Harga Asli vs Prediksi Harga Daging Sapi 90 Hari Kedepan')
plt.xlabel('Tanggal')
plt.ylabel('Harga (Rp/Kg)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

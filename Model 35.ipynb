# %% [markdown]
# # Import Package Yang Dibutuhkan

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %% [markdown]
# # Ambil dan Baca File Dataset

# %%
df = pd.read_csv("DATASET/dataset rata-rata.csv", sep=';') # membaca dataset dari file CSV dengan pemisah titik koma
df['Tanggal'] = pd.to_datetime(df['Tanggal'], dayfirst=True) # ubah kolom 'Tanggal' menjadi tipe datetime dan mengatur format hari-bulan-tahun
df = df.sort_values('Tanggal') # urutkan data berdasarkan tanggal
df.set_index('Tanggal', inplace=True) # set kolom 'Tanggal' sebagai index

# %%
df.head() # menampilkan 5 baris pertama dari dataset
# Out:
#                Harga
# Tanggal
# 2018-01-02  122150.0
# 2018-01-03  126450.0
# 2018-01-04  107850.0
# 2018-01-05  121550.0
# 2018-01-08  121150.0

# %%
df.tail() # menampilkan 5 baris terakhir dari dataset
# Out:
#                Harga
# Tanggal
# 2025-05-26  156100.0
# 2025-05-27  156100.0
# 2025-05-28  156100.0
# 2025-05-29  156100.0
# 2025-05-30  156100.0

# %%
plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(df.index, df['Harga'], label='Harga') # plot harga daging sapi
plt.title('Harga Daging Sapi 2018-2025') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi

# %%
print(df['Harga'].describe())
# Out:
# count      1908.000000
# mean     141551.808176
# std       13421.208265
# min      102650.000000
# 25%      131350.000000
# 50%      135150.000000
# 75%      156650.000000
# max      189000.000000
# Name: Harga, dtype: float64

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Pengecekan Nilai Kosong

# %%
print('Jumlah nilai kosong:') # menampilkan jumlah nilai kosong
df.isnull().sum() # menampilkan jumlah nilai kosong pada setiap kolom
# Out:
# Jumlah nilai kosong:
# Harga    14
# dtype: int64

# %% [markdown]
# Pengecekan Nilai Duplikat

# %%
duplicate_dates = df.index.duplicated().sum() # menghitung jumlah tanggal duplikat pada index
print(f'Jumlah tanggal duplikat pada index: {duplicate_dates}') # menampilkan jumlah tanggal duplikat pada index
# Out:
# Jumlah tanggal duplikat pada index: 0

# %% [markdown]
# Penghapusan Nilai Kosong

# %%
df = df.dropna() # menghapus baris yang memiliki nilai kosong

# %%
df.isnull().sum() # menampilkan jumlah nilai kosong setelah penghapusan
# Out:
# Harga    0
# dtype: int64

# %% [markdown]
# Normalisasi data dengan MinMaxScaler

# %%
scaler = MinMaxScaler() # inisialisasi MinMaxScaler untuk normalisasi data
scaled_data = scaler.fit_transform(df[['Harga']]) # normalisasi data harga daging sapi

# %%
print('Data setelah normalisasi:') # menampilkan data setelah normalisasi
scaled_df = pd.DataFrame(scaled_data, index=df.index, columns=['Harga_Daging_Sapi']) # membuat DataFrame baru dengan data yang sudah dinormalisasi
scaled_df.head() # menampilkan 5 baris pertama dari data yang sudah dinormalisasi
# Out:
# Data setelah normalisasi:
#             Harga_Daging_Sapi
# Tanggal
# 2018-01-02           0.225825
# 2018-01-03           0.275622
# 2018-01-04           0.060220
# 2018-01-05           0.218877
# 2018-01-08           0.214244

# %% [markdown]
# ## Membuat Fitur dan Target Menggunakan Sliding Window

# %%
def create_dataset(dataset, time_step=30): # fungsi untuk membuat dataset dengan time step 30
    X, y = [], [] # inisialisasi list untuk fitur (X) dan target (y)
    for i in range(len(dataset) - time_step): # iterasi untuk membuat fitur dan target
        X.append(dataset[i:(i + time_step), 0]) # mengambil data dari indeks i sampai i + time_step
        y.append(dataset[i + time_step, 0]) # target adalah data pada indeks i + time_step
    return np.array(X), np.array(y) # mengembalikan fitur dan target sebagai array numpy
time_step = 30 # mendefinisikan time step untuk dataset
X, y = create_dataset(scaled_data, time_step) # membuat dataset dengan time step 30
X = X.reshape(X.shape[0], X.shape[1], 1) # mengubah bentuk X menjadi 3D array untuk LSTM input

# %% [markdown]
# # Membangun Model LSTM

# %% [markdown]
# Membagi Rasio Data Latih dan Uji

# %%
train_size = int(len(X) * 0.8) # mendefinisikan ukuran data latih sebagai 80% dari total data
X_train, X_test = X[:train_size], X[train_size:] # membagi data menjadi data latih dan data uji
y_train, y_test = y[:train_size], y[train_size:] # membagi target menjadi data latih dan data uji

# %% [markdown]
# Membangun Hidden Layer LSTM

# %%
model = Sequential() # inisialisasi model Sequential
model.add(LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], 1))) # menambahkan layer LSTM pertama dengan 128 unit dan return_sequences=True
model.add(Dropout(0.2)) # menambahkan layer Dropout untuk mengurangi overfitting
model.add(LSTM(128)) # menambahkan layer LSTM kedua dengan 128 unit
model.add(Dropout(0.2)) # menambahkan layer Dropout kedua
model.add(Dense(1)) # menambahkan layer Dense output dengan 1 unit
optimizer = Adam(learning_rate=0.01) # inisialisasi optimizer Adam dengan learning rate 0.01
model.compile(optimizer=optimizer, loss='mean_squared_error') # mengkompilasi model dengan loss function mean squared error
# Out:
# c:\Users\mfasa\Documents\Ngoding\Deep Learning\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Training Model

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=250, batch_size=32, verbose=1) # melatih model dengan data latih dan validasi, selama 250 epoch dengan batch size 32
# Out:
# Epoch 1/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.1094 - val_loss: 0.0053
# Epoch 2/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 3/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 4/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 5/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 6/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 7/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 8/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 9/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 10/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 11/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 12/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 13/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 14/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 15/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 16/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 17/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 18/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 19/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 20/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 21/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 22/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 23/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 24/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 25/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 26/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 27/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 28/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 29/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 30/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 31/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 32/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 33/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 34/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 35/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 36/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 37/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 38/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 39/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 40/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 41/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 42/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 43/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 44/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 45/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 46/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 47/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 48/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 49/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 50/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 51/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 52/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 53/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 54/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 55/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 56/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 57/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 58/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 59/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 60/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 61/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 62/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 63/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 64/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 65/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 66/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 67/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 68/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 69/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 70/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 71/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 72/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 73/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 74/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 75/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 76/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 77/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 78/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 79/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 80/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 81/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 82/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 83/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 84/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 85/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 86/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 87/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 88/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 89/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 90/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 91/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 92/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 93/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 94/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 95/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 96/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 97/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 98/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 99/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 100/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 101/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0012 - val_loss: 0.0057
# Epoch 102/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 103/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 104/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 105/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 106/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 107/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 108/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 109/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 110/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 111/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 112/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 113/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 114/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 115/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 116/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 117/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 118/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 119/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 120/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0018 - val_loss: 0.0036
# Epoch 121/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 122/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 123/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 124/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 125/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 126/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 127/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 128/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 129/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 130/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 131/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 132/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 133/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 134/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 135/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 136/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 137/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 138/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 139/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 140/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 141/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 142/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 143/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 144/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 145/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 146/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 147/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0019 - val_loss: 0.0058
# Epoch 148/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 149/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 150/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 151/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 152/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 153/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 154/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 155/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 156/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 157/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 158/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 159/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 160/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 161/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 162/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 163/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 164/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 165/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 166/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 167/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 168/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 169/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 170/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 171/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 172/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 173/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 174/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 175/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 176/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 177/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 178/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 179/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 180/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 181/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 182/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 183/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 184/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 185/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 186/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 187/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 188/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 189/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 190/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 191/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 192/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 193/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 194/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 195/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 196/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 197/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 198/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 199/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 200/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 201/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 202/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 203/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 204/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 205/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 206/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 207/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 208/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 209/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 210/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 211/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 212/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 213/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 214/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 215/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 216/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 217/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 218/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 219/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 220/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 221/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 222/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 223/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 224/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 225/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 226/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 227/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 228/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 229/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 230/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 231/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 232/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 233/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 234/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 235/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 236/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 237/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 238/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 239/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 240/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 241/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 242/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 243/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 244/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 245/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 246/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 247/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 248/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 249/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 250/250
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0013 - val_loss: 0.0028

# %%
train_predict = model.predict(X_train) # melakukan prediksi pada data latih
test_predict = model.predict(X_test) # melakukan prediksi pada data uji
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %% [markdown]
# # Visualisasi Hasil Training

# %%
train_predict = scaler.inverse_transform(train_predict) # mengembalikan skala prediksi data latih
test_predict = scaler.inverse_transform(test_predict) # mengembalikan skala prediksi data uji
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1)) # mengembalikan skala target data latih
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1)) # mengembalikan skala target data uji

# %%
train_dates = df.index[time_step:train_size + time_step] # menagmbil tanggal untuk data latih
test_dates = df.index[train_size + time_step:] # mengambil tanggal untuk data uji

plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(train_dates, y_train_inv, label='Data Training Asli') # plot data asli training
plt.plot(train_dates, train_predict, label='Prediksi Training') # plot prediksi training
plt.plot(test_dates, y_test_inv, label='Data Testing Asli') # plot data asli testing
plt.plot(test_dates, test_predict, label='Prediksi Testing') # plot prediksi testing
plt.legend() # menampilkan legenda
plt.title('Prediksi Harga Daging Sapi dengan LSTM') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik prediksi harga daging sapi

# %% [markdown]
# # Evaluasi Model

# %%
# Hitung MSE
mse = mean_squared_error(y_test_inv, test_predict) # Hitung Mean Squared Error (MSE)
print(f'Mean Squared Error (MSE): {mse}') # menampilkan MSE

# Hitung RMSE
rmse = np.sqrt(mse) # Hitung Root Mean Squared Error (RMSE)
print(f'Root Mean Squared Error (RMSE): {rmse}') # menampilkan RMSE

# Hitung MAE
mae = mean_absolute_error(y_test_inv, test_predict) # Hitung Mean Absolute Error (MAE)
print(f'Mean Absolute Error (MAE): {mae}') # menampilkan MAE

# Hitung MAPE
mape = np.mean(np.abs((y_test_inv - test_predict) / (y_test_inv + 1e-8))) * 100 # Hitung Mean Absolute Percentage Error (MAPE) dan menghindari pembagian dengan nol
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%') # menampilkan MAPE
# Out:
# Mean Squared Error (MSE): 20577073.221456323
# Root Mean Squared Error (RMSE): 4536.1958976058695
# Mean Absolute Error (MAE): 4077.5792054521276
# Mean Absolute Percentage Error (MAPE): 2.58%

# %% [markdown]
# # Prediksi 90 Hari Kedepan

# %% [markdown]
# Prediksi 90 hari ke depan (normalized)

# %%
future_steps = 90 # menentukan jumlah langkah prediksi ke depan
last_input = scaled_data[-time_step:].reshape(1, time_step, 1) # mengambil data terakhir untuk prediksi dan mengubah bentuknya menjadi 3D array
future_preds_90_norm = [] # inisialisasi list untuk menyimpan prediksi 90 hari ke depan

for _ in range(future_steps): # loop untuk melakukan prediksi 90 hari ke depan
    pred = model.predict(last_input, verbose=0) # melakukan prediksi dengan model
    future_preds_90_norm.append(pred[0, 0])  # menyimpan prediksi ke dalam list
    last_input = np.append(last_input[:, 1:, :], [[[pred[0, 0]]]], axis=1) # memperbarui input terakhir dengan prediksi baru

# %% [markdown]
# Denormalisasi hasil prediksi

# %%
future_preds_90_actual = scaler.inverse_transform(np.array(future_preds_90_norm).reshape(-1, 1)).flatten().astype(int) # denormalisasi hasil prediksi dan mengubahnya menjadi integer

# %% [markdown]
# Buat DataFrame untuk Tabel

# %%
last_date = df.index[-1] # mengambil tanggal terakhir dari data historis
future_dates_90 = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=future_steps) # membuat rentang tanggal untuk 90 hari ke depan

# Versi Normalized
df_future_90_norm = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga dinormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Normalized)': np.round(future_preds_90_norm, 6)
})

# Versi DENORMALIZED
df_future_90_actual = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga denormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Rp/Kg)': future_preds_90_actual
})

# Versi untuk plot/gabung (pakai index datetime)
df_future_90_plot = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan index datetime
    'Tanggal': future_dates_90,
    'Prediksi Harga Daging Sapi': future_preds_90_actual
}).set_index('Tanggal')

# %% [markdown]
# Gabungkan dengan data historis

# %%
df_all = pd.concat([ # menggabungkan DataFrame historis dengan prediksi 90 hari ke depan
    df[['Harga']], # mengambil kolom 'Harga_Daging_Sapi' dari DataFrame historis
    df_future_90_plot.rename(columns={'Prediksi Harga Daging Sapi': 'Harga'}) # mengganti nama kolom untuk konsistensi
])

# %% [markdown]
# Tampilkan tabel versi normalisasi dan denormalisasi

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Normalisasi):")
print(df_future_90_norm.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Normalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Normalized)
#   1 2025-05-31                                 0.579299
#   2 2025-06-01                                 0.567423
#   3 2025-06-02                                 0.554416
#   4 2025-06-03                                 0.541763
#   5 2025-06-04                                 0.527570
#   6 2025-06-05                                 0.512435
#   7 2025-06-06                                 0.497030
#   8 2025-06-07                                 0.481341
#   9 2025-06-08                                 0.465124
#  10 2025-06-09                                 0.448484
#  11 2025-06-10                                 0.431327
#  12 2025-06-11                                 0.413932
#  13 2025-06-12                                 0.395981
#  14 2025-06-13                                 0.377631
#  15 2025-06-14                                 0.358915
#  16 2025-06-15                                 0.340226
#  17 2025-06-16                                 0.321759
#  18 2025-06-17                                 0.304312
#  19 2025-06-18                                 0.288500
#  20 2025-06-19                                 0.275017
#  21 2025-06-20                                 0.264256
#  22 2025-06-21                                 0.256124
#  23 2025-06-22                                 0.250133
#  24 2025-06-23                                 0.245614
#  25 2025-06-24                                 0.242043
#  26 2025-06-25                                 0.239125
#  27 2025-06-26                                 0.236796
#  28 2025-06-27                                 0.234925
#  29 2025-06-28                                 0.233504
#  30 2025-06-29                                 0.232486
#  31 2025-06-30                                 0.232050
#  32 2025-07-01                                 0.231697
#  33 2025-07-02                                 0.231375
#  34 2025-07-03                                 0.231040
#  35 2025-07-04                                 0.230642
#  36 2025-07-05                                 0.230269
#  37 2025-07-06                                 0.229927
#  38 2025-07-07                                 0.229652
#  39 2025-07-08                                 0.229410
#  40 2025-07-09                                 0.229165
#  41 2025-07-10                                 0.228880
#  42 2025-07-11                                 0.228547
#  43 2025-07-12                                 0.228190
#  44 2025-07-13                                 0.227850
#  45 2025-07-14                                 0.227565
#  46 2025-07-15                                 0.227354
#  47 2025-07-16                                 0.227206
#  48 2025-07-17                                 0.227095
#  49 2025-07-18                                 0.226997
#  50 2025-07-19                                 0.226900
#  51 2025-07-20                                 0.226805
#  52 2025-07-21                                 0.226719
#  53 2025-07-22                                 0.226649
#  54 2025-07-23                                 0.226598
#  55 2025-07-24                                 0.226562
#  56 2025-07-25                                 0.226533
#  57 2025-07-26                                 0.226505
#  58 2025-07-27                                 0.226475
#  59 2025-07-28                                 0.226442
#  60 2025-07-29                                 0.226411
#  61 2025-07-30                                 0.226384
#  62 2025-07-31                                 0.226363
#  63 2025-08-01                                 0.226347
#  64 2025-08-02                                 0.226334
#  65 2025-08-03                                 0.226321
#  66 2025-08-04                                 0.226309
#  67 2025-08-05                                 0.226296
#  68 2025-08-06                                 0.226285
#  69 2025-08-07                                 0.226275
#  70 2025-08-08                                 0.226268
#  71 2025-08-09                                 0.226263
#  72 2025-08-10                                 0.226260
#  73 2025-08-11                                 0.226257
#  74 2025-08-12                                 0.226253
#  75 2025-08-13                                 0.226250
#  76 2025-08-14                                 0.226246
#  77 2025-08-15                                 0.226243
#  78 2025-08-16                                 0.226241
#  79 2025-08-17                                 0.226240
#  80 2025-08-18                                 0.226239
#  81 2025-08-19                                 0.226238
#  82 2025-08-20                                 0.226236
#  83 2025-08-21                                 0.226235
#  84 2025-08-22                                 0.226234
#  85 2025-08-23                                 0.226233
#  86 2025-08-24                                 0.226232
#  87 2025-08-25                                 0.226232
#  88 2025-08-26                                 0.226232
#  89 2025-08-27                                 0.226231
#  90 2025-08-28                                 0.226231

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Denormalisasi):")
print(df_future_90_actual.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Denormalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Rp/Kg)
#   1 2025-05-31                              152672
#   2 2025-06-01                              151646
#   3 2025-06-02                              150523
#   4 2025-06-03                              149431
#   5 2025-06-04                              148205
#   6 2025-06-05                              146898
#   7 2025-06-06                              145568
#   8 2025-06-07                              144213
#   9 2025-06-08                              142813
#  10 2025-06-09                              141376
#  11 2025-06-10                              139895
#  12 2025-06-11                              138393
#  13 2025-06-12                              136842
#  14 2025-06-13                              135258
#  15 2025-06-14                              133642
#  16 2025-06-15                              132028
#  17 2025-06-16                              130433
#  18 2025-06-17                              128927
#  19 2025-06-18                              127561
#  20 2025-06-19                              126397
#  21 2025-06-20                              125468
#  22 2025-06-21                              124766
#  23 2025-06-22                              124249
#  24 2025-06-23                              123858
#  25 2025-06-24                              123550
#  26 2025-06-25                              123298
#  27 2025-06-26                              123097
#  28 2025-06-27                              122935
#  29 2025-06-28                              122813
#  30 2025-06-29                              122725
#  31 2025-06-30                              122687
#  32 2025-07-01                              122657
#  33 2025-07-02                              122629
#  34 2025-07-03                              122600
#  35 2025-07-04                              122565
#  36 2025-07-05                              122533
#  37 2025-07-06                              122504
#  38 2025-07-07                              122480
#  39 2025-07-08                              122459
#  40 2025-07-09                              122438
#  41 2025-07-10                              122413
#  42 2025-07-11                              122385
#  43 2025-07-12                              122354
#  44 2025-07-13                              122324
#  45 2025-07-14                              122300
#  46 2025-07-15                              122282
#  47 2025-07-16                              122269
#  48 2025-07-17                              122259
#  49 2025-07-18                              122251
#  50 2025-07-19                              122242
#  51 2025-07-20                              122234
#  52 2025-07-21                              122227
#  53 2025-07-22                              122221
#  54 2025-07-23                              122216
#  55 2025-07-24                              122213
#  56 2025-07-25                              122211
#  57 2025-07-26                              122208
#  58 2025-07-27                              122206
#  59 2025-07-28                              122203
#  60 2025-07-29                              122200
#  61 2025-07-30                              122198
#  62 2025-07-31                              122196
#  63 2025-08-01                              122195
#  64 2025-08-02                              122193
#  65 2025-08-03                              122192
#  66 2025-08-04                              122191
#  67 2025-08-05                              122190
#  68 2025-08-06                              122189
#  69 2025-08-07                              122188
#  70 2025-08-08                              122188
#  71 2025-08-09                              122187
#  72 2025-08-10                              122187
#  73 2025-08-11                              122187
#  74 2025-08-12                              122186
#  75 2025-08-13                              122186
#  76 2025-08-14                              122186
#  77 2025-08-15                              122186
#  78 2025-08-16                              122185
#  79 2025-08-17                              122185
#  80 2025-08-18                              122185
#  81 2025-08-19                              122185
#  82 2025-08-20                              122185
#  83 2025-08-21                              122185
#  84 2025-08-22                              122185
#  85 2025-08-23                              122185
#  86 2025-08-24                              122185
#  87 2025-08-25                              122185
#  88 2025-08-26                              122185
#  89 2025-08-27                              122185
#  90 2025-08-28                              122185

# %% [markdown]
# Tampilkan plot harga historis 90 hari + prediksi 90 hari ke depan

# %%
window_hist = 90 # menentukan jumlah hari historis yang akan ditampilkan
last_hist_dates = df.index[-window_hist:] # mengambil tanggal historis terakhir
last_hist_prices = df['Harga'].iloc[-window_hist:] # mengambil harga historis terakhir

future_dates_90_plot = df_future_90_plot.index # mengambil tanggal untuk prediksi 90 hari ke depan
future_prices_90_plot = df_future_90_plot['Prediksi Harga Daging Sapi'] # mengambil harga prediksi 90 hari ke depan

plt.figure(figsize=(14,7)) # plot ukuran grafik
plt.plot(last_hist_dates, last_hist_prices, label=f'Harga Asli {window_hist} Hari Terakhir', color='blue') # plot harga historis terakhir
plt.plot(future_dates_90_plot, future_prices_90_plot, label='Prediksi 90 Hari Kedepan', color='orange', linestyle='--') # plot prediksi 90 hari ke depan
plt.axvline(x=last_hist_dates[-1], color='grey', linestyle=':', label='Batas Data Historis') # garis vertikal untuk batas data historis
plt.title(f'Harga Daging Sapi: {window_hist} Hari Terakhir & Prediksi 90 Hari Kedepan') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.xticks(rotation=45) # rotasi label sumbu x agar lebih mudah dibaca
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi dengan prediksi 90 hari ke depan

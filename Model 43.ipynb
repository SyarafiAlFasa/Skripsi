# %% [markdown]
# # Import Package Yang Dibutuhkan

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %% [markdown]
# # Ambil dan Baca File Dataset

# %%
df = pd.read_csv("DATASET/dataset rata-rata.csv", sep=';') # membaca dataset dari file CSV dengan pemisah titik koma
df['Tanggal'] = pd.to_datetime(df['Tanggal'], dayfirst=True) # ubah kolom 'Tanggal' menjadi tipe datetime dan mengatur format hari-bulan-tahun
df = df.sort_values('Tanggal') # urutkan data berdasarkan tanggal
df.set_index('Tanggal', inplace=True) # set kolom 'Tanggal' sebagai index

# %%
df.head() # menampilkan 5 baris pertama dari dataset
# Out:
#                Harga
# Tanggal
# 2018-01-02  122150.0
# 2018-01-03  126450.0
# 2018-01-04  107850.0
# 2018-01-05  121550.0
# 2018-01-08  121150.0

# %%
df.tail() # menampilkan 5 baris terakhir dari dataset
# Out:
#                Harga
# Tanggal
# 2025-05-26  156100.0
# 2025-05-27  156100.0
# 2025-05-28  156100.0
# 2025-05-29  156100.0
# 2025-05-30  156100.0

# %%
plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(df.index, df['Harga'], label='Harga') # plot harga daging sapi
plt.title('Harga Daging Sapi 2018-2025') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi

# %%
print(df['Harga'].describe())
# Out:
# count      1908.000000
# mean     141551.808176
# std       13421.208265
# min      102650.000000
# 25%      131350.000000
# 50%      135150.000000
# 75%      156650.000000
# max      189000.000000
# Name: Harga, dtype: float64

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Pengecekan Nilai Kosong

# %%
print('Jumlah nilai kosong:') # menampilkan jumlah nilai kosong
df.isnull().sum() # menampilkan jumlah nilai kosong pada setiap kolom
# Out:
# Jumlah nilai kosong:
# Harga    14
# dtype: int64

# %% [markdown]
# Pengecekan Nilai Duplikat

# %%
duplicate_dates = df.index.duplicated().sum() # menghitung jumlah tanggal duplikat pada index
print(f'Jumlah tanggal duplikat pada index: {duplicate_dates}') # menampilkan jumlah tanggal duplikat pada index
# Out:
# Jumlah tanggal duplikat pada index: 0

# %% [markdown]
# Penghapusan Nilai Kosong

# %%
df = df.dropna() # menghapus baris yang memiliki nilai kosong

# %%
df.isnull().sum() # menampilkan jumlah nilai kosong setelah penghapusan
# Out:
# Harga    0
# dtype: int64

# %% [markdown]
# Normalisasi data dengan MinMaxScaler

# %%
scaler = MinMaxScaler() # inisialisasi MinMaxScaler untuk normalisasi data
scaled_data = scaler.fit_transform(df[['Harga']]) # normalisasi data harga daging sapi

# %%
print('Data setelah normalisasi:') # menampilkan data setelah normalisasi
scaled_df = pd.DataFrame(scaled_data, index=df.index, columns=['Harga_Daging_Sapi']) # membuat DataFrame baru dengan data yang sudah dinormalisasi
scaled_df.head() # menampilkan 5 baris pertama dari data yang sudah dinormalisasi
# Out:
# Data setelah normalisasi:
#             Harga_Daging_Sapi
# Tanggal
# 2018-01-02           0.225825
# 2018-01-03           0.275622
# 2018-01-04           0.060220
# 2018-01-05           0.218877
# 2018-01-08           0.214244

# %% [markdown]
# ## Membuat Fitur dan Target Menggunakan Sliding Window

# %%
def create_dataset(dataset, time_step=30): # fungsi untuk membuat dataset dengan time step 30
    X, y = [], [] # inisialisasi list untuk fitur (X) dan target (y)
    for i in range(len(dataset) - time_step): # iterasi untuk membuat fitur dan target
        X.append(dataset[i:(i + time_step), 0]) # mengambil data dari indeks i sampai i + time_step
        y.append(dataset[i + time_step, 0]) # target adalah data pada indeks i + time_step
    return np.array(X), np.array(y) # mengembalikan fitur dan target sebagai array numpy
time_step = 30 # mendefinisikan time step untuk dataset
X, y = create_dataset(scaled_data, time_step) # membuat dataset dengan time step 30
X = X.reshape(X.shape[0], X.shape[1], 1) # mengubah bentuk X menjadi 3D array untuk LSTM input

# %% [markdown]
# # Membangun Model LSTM

# %% [markdown]
# Membagi Rasio Data Latih dan Uji

# %%
train_size = int(len(X) * 0.9) # mendefinisikan ukuran data latih sebagai 90% dari total data
X_train, X_test = X[:train_size], X[train_size:] # membagi data menjadi data latih dan data uji
y_train, y_test = y[:train_size], y[train_size:] # membagi target menjadi data latih dan data uji

# %% [markdown]
# Membangun Hidden Layer LSTM

# %%
model = Sequential() # inisialisasi model Sequential
model.add(LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], 1))) # menambahkan layer LSTM pertama dengan 64 unit dan return_sequences=True
model.add(Dropout(0.2)) # menambahkan layer Dropout untuk mengurangi overfitting
model.add(LSTM(64)) # menambahkan layer LSTM kedua dengan 64 unit
model.add(Dropout(0.2)) # menambahkan layer Dropout kedua
model.add(Dense(1)) # menambahkan layer Dense output dengan 1 unit
optimizer = Adam(learning_rate=0.001) # inisialisasi optimizer Adam dengan learning rate 0.001
model.compile(optimizer=optimizer, loss='mean_squared_error') # mengkompilasi model dengan loss function mean squared error
# Out:
# c:\Users\mfasa\Documents\Ngoding\Deep Learning\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Training Model

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1) # melatih model dengan data latih dan validasi, selama 100 epoch dengan batch size 32
# Out:
# Epoch 1/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - loss: 0.0644 - val_loss: 0.0012
# Epoch 2/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 3/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 4/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 5/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 6/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 7/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 8/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 9/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 10/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 11/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 12/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 13/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 14/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 15/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 16/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 17/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 18/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 19/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 20/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 21/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 22/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 23/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 24/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 25/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 26/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 27/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 28/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 29/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 30/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 31/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 32/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 33/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 34/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 35/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 36/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 37/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 38/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 39/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 40/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 41/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 42/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 43/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 44/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 45/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 46/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 47/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 48/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 49/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 50/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 51/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 52/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 53/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 54/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 55/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 56/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 57/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 58/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 59/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 60/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 61/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 62/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 63/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 64/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 65/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 66/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 67/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 68/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 69/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 70/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 71/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 72/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 73/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 74/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 75/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 76/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 77/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 78/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 79/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 80/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 81/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 82/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 83/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 84/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 85/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 86/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 87/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 88/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 89/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 90/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 91/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 92/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 93/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 94/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 95/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 96/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 97/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 98/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 99/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 100/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0016 - val_loss: 0.0012

# %%
train_predict = model.predict(X_train) # melakukan prediksi pada data latih
test_predict = model.predict(X_test) # melakukan prediksi pada data uji
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# # Visualisasi Hasil Training

# %%
train_predict = scaler.inverse_transform(train_predict) # mengembalikan skala prediksi data latih
test_predict = scaler.inverse_transform(test_predict) # mengembalikan skala prediksi data uji
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1)) # mengembalikan skala target data latih
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1)) # mengembalikan skala target data uji

# %%
train_dates = df.index[time_step:train_size + time_step] # menagmbil tanggal untuk data latih
test_dates = df.index[train_size + time_step:] # mengambil tanggal untuk data uji

plt.figure(figsize=(12,6)) # plot ukuran grafik
plt.plot(train_dates, y_train_inv, label='Data Training Asli') # plot data asli training
plt.plot(train_dates, train_predict, label='Prediksi Training') # plot prediksi training
plt.plot(test_dates, y_test_inv, label='Data Testing Asli') # plot data asli testing
plt.plot(test_dates, test_predict, label='Prediksi Testing') # plot prediksi testing
plt.legend() # menampilkan legenda
plt.title('Prediksi Harga Daging Sapi dengan LSTM') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik prediksi harga daging sapi

# %% [markdown]
# # Evaluasi Model

# %%
# Hitung MSE
mse = mean_squared_error(y_test_inv, test_predict) # Hitung Mean Squared Error (MSE)
print(f'Mean Squared Error (MSE): {mse}') # menampilkan MSE

# Hitung RMSE
rmse = np.sqrt(mse) # Hitung Root Mean Squared Error (RMSE)
print(f'Root Mean Squared Error (RMSE): {rmse}') # menampilkan RMSE

# Hitung MAE
mae = mean_absolute_error(y_test_inv, test_predict) # Hitung Mean Absolute Error (MAE)
print(f'Mean Absolute Error (MAE): {mae}') # menampilkan MAE

# Hitung MAPE
mape = np.mean(np.abs((y_test_inv - test_predict) / (y_test_inv + 1e-8))) * 100 # Hitung Mean Absolute Percentage Error (MAPE) dan menghindari pembagian dengan nol
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%') # menampilkan MAPE
# Out:
# Mean Squared Error (MSE): 8906833.946378667
# Root Mean Squared Error (RMSE): 2984.4319302638933
# Mean Absolute Error (MAE): 1749.3051030585107
# Mean Absolute Percentage Error (MAPE): 1.12%

# %% [markdown]
# # Prediksi 90 Hari Kedepan

# %% [markdown]
# Prediksi 90 hari ke depan (normalized)

# %%
future_steps = 90 # menentukan jumlah langkah prediksi ke depan
last_input = scaled_data[-time_step:].reshape(1, time_step, 1) # mengambil data terakhir untuk prediksi dan mengubah bentuknya menjadi 3D array
future_preds_90_norm = [] # inisialisasi list untuk menyimpan prediksi 90 hari ke depan

for _ in range(future_steps): # loop untuk melakukan prediksi 90 hari ke depan
    pred = model.predict(last_input, verbose=0) # melakukan prediksi dengan model
    future_preds_90_norm.append(pred[0, 0])  # menyimpan prediksi ke dalam list
    last_input = np.append(last_input[:, 1:, :], [[[pred[0, 0]]]], axis=1) # memperbarui input terakhir dengan prediksi baru

# %% [markdown]
# Denormalisasi hasil prediksi

# %%
future_preds_90_actual = scaler.inverse_transform(np.array(future_preds_90_norm).reshape(-1, 1)).flatten().astype(int) # denormalisasi hasil prediksi dan mengubahnya menjadi integer

# %% [markdown]
# Buat DataFrame untuk Tabel

# %%
last_date = df.index[-1] # mengambil tanggal terakhir dari data historis
future_dates_90 = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=future_steps) # membuat rentang tanggal untuk 90 hari ke depan

# Versi Normalized
df_future_90_norm = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga dinormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Normalized)': np.round(future_preds_90_norm, 6)
})

# Versi DENORMALIZED
df_future_90_actual = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan harga denormalisasi
    'No': range(1, future_steps + 1),
    'Tanggal': future_dates_90.strftime('%Y-%m-%d'),
    'Prediksi Harga Daging Sapi (Rp/Kg)': future_preds_90_actual
})

# Versi untuk plot/gabung (pakai index datetime)
df_future_90_plot = pd.DataFrame({ # membuat DataFrame untuk prediksi 90 hari ke depan dengan index datetime
    'Tanggal': future_dates_90,
    'Prediksi Harga Daging Sapi': future_preds_90_actual
}).set_index('Tanggal')

# %% [markdown]
# Gabungkan dengan data historis

# %%
df_all = pd.concat([ # menggabungkan DataFrame historis dengan prediksi 90 hari ke depan
    df[['Harga']], # mengambil kolom 'Harga_Daging_Sapi' dari DataFrame historis
    df_future_90_plot.rename(columns={'Prediksi Harga Daging Sapi': 'Harga'}) # mengganti nama kolom untuk konsistensi
])

# %% [markdown]
# Tampilkan tabel versi normalisasi dan denormalisasi

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Normalisasi):")
print(df_future_90_norm.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Normalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Normalized)
#   1 2025-05-31                                 0.613626
#   2 2025-06-01                                 0.612185
#   3 2025-06-02                                 0.610708
#   4 2025-06-03                                 0.609373
#   5 2025-06-04                                 0.608053
#   6 2025-06-05                                 0.606972
#   7 2025-06-06                                 0.605995
#   8 2025-06-07                                 0.605096
#   9 2025-06-08                                 0.604247
#  10 2025-06-09                                 0.603418
#  11 2025-06-10                                 0.602598
#  12 2025-06-11                                 0.601776
#  13 2025-06-12                                 0.600955
#  14 2025-06-13                                 0.600126
#  15 2025-06-14                                 0.599288
#  16 2025-06-15                                 0.598437
#  17 2025-06-16                                 0.597583
#  18 2025-06-17                                 0.596722
#  19 2025-06-18                                 0.595863
#  20 2025-06-19                                 0.595007
#  21 2025-06-20                                 0.594156
#  22 2025-06-21                                 0.593314
#  23 2025-06-22                                 0.592481
#  24 2025-06-23                                 0.591659
#  25 2025-06-24                                 0.590850
#  26 2025-06-25                                 0.590052
#  27 2025-06-26                                 0.589268
#  28 2025-06-27                                 0.588496
#  29 2025-06-28                                 0.587736
#  30 2025-06-29                                 0.586989
#  31 2025-06-30                                 0.586253
#  32 2025-07-01                                 0.585523
#  33 2025-07-02                                 0.584802
#  34 2025-07-03                                 0.584088
#  35 2025-07-04                                 0.583381
#  36 2025-07-05                                 0.582681
#  37 2025-07-06                                 0.581988
#  38 2025-07-07                                 0.581302
#  39 2025-07-08                                 0.580622
#  40 2025-07-09                                 0.579950
#  41 2025-07-10                                 0.579284
#  42 2025-07-11                                 0.578625
#  43 2025-07-12                                 0.577974
#  44 2025-07-13                                 0.577330
#  45 2025-07-14                                 0.576692
#  46 2025-07-15                                 0.576062
#  47 2025-07-16                                 0.575438
#  48 2025-07-17                                 0.574822
#  49 2025-07-18                                 0.574212
#  50 2025-07-19                                 0.573608
#  51 2025-07-20                                 0.573011
#  52 2025-07-21                                 0.572420
#  53 2025-07-22                                 0.571836
#  54 2025-07-23                                 0.571257
#  55 2025-07-24                                 0.570685
#  56 2025-07-25                                 0.570118
#  57 2025-07-26                                 0.569558
#  58 2025-07-27                                 0.569003
#  59 2025-07-28                                 0.568454
#  60 2025-07-29                                 0.567910
#  61 2025-07-30                                 0.567372
#  62 2025-07-31                                 0.566840
#  63 2025-08-01                                 0.566313
#  64 2025-08-02                                 0.565791
#  65 2025-08-03                                 0.565275
#  66 2025-08-04                                 0.564764
#  67 2025-08-05                                 0.564258
#  68 2025-08-06                                 0.563757
#  69 2025-08-07                                 0.563262
#  70 2025-08-08                                 0.562771
#  71 2025-08-09                                 0.562285
#  72 2025-08-10                                 0.561804
#  73 2025-08-11                                 0.561328
#  74 2025-08-12                                 0.560857
#  75 2025-08-13                                 0.560390
#  76 2025-08-14                                 0.559928
#  77 2025-08-15                                 0.559471
#  78 2025-08-16                                 0.559018
#  79 2025-08-17                                 0.558570
#  80 2025-08-18                                 0.558126
#  81 2025-08-19                                 0.557686
#  82 2025-08-20                                 0.557251
#  83 2025-08-21                                 0.556820
#  84 2025-08-22                                 0.556393
#  85 2025-08-23                                 0.555971
#  86 2025-08-24                                 0.555552
#  87 2025-08-25                                 0.555138
#  88 2025-08-26                                 0.554727
#  89 2025-08-27                                 0.554321
#  90 2025-08-28                                 0.553918

# %%
print("\nHasil Prediksi 90 Hari Ke Depan (Denormalisasi):")
print(df_future_90_actual.to_string(index=False))
# Out:
# Hasil Prediksi 90 Hari Ke Depan (Denormalisasi):
#  No    Tanggal  Prediksi Harga Daging Sapi (Rp/Kg)
#   1 2025-05-31                              155636
#   2 2025-06-01                              155512
#   3 2025-06-02                              155384
#   4 2025-06-03                              155269
#   5 2025-06-04                              155155
#   6 2025-06-05                              155061
#   7 2025-06-06                              154977
#   8 2025-06-07                              154900
#   9 2025-06-08                              154826
#  10 2025-06-09                              154755
#  11 2025-06-10                              154684
#  12 2025-06-11                              154613
#  13 2025-06-12                              154542
#  14 2025-06-13                              154470
#  15 2025-06-14                              154398
#  16 2025-06-15                              154325
#  17 2025-06-16                              154251
#  18 2025-06-17                              154176
#  19 2025-06-18                              154102
#  20 2025-06-19                              154028
#  21 2025-06-20                              153955
#  22 2025-06-21                              153882
#  23 2025-06-22                              153810
#  24 2025-06-23                              153739
#  25 2025-06-24                              153669
#  26 2025-06-25                              153601
#  27 2025-06-26                              153533
#  28 2025-06-27                              153466
#  29 2025-06-28                              153401
#  30 2025-06-29                              153336
#  31 2025-06-30                              153272
#  32 2025-07-01                              153209
#  33 2025-07-02                              153147
#  34 2025-07-03                              153086
#  35 2025-07-04                              153024
#  36 2025-07-05                              152964
#  37 2025-07-06                              152904
#  38 2025-07-07                              152845
#  39 2025-07-08                              152786
#  40 2025-07-09                              152728
#  41 2025-07-10                              152671
#  42 2025-07-11                              152614
#  43 2025-07-12                              152558
#  44 2025-07-13                              152502
#  45 2025-07-14                              152447
#  46 2025-07-15                              152392
#  47 2025-07-16                              152339
#  48 2025-07-17                              152285
#  49 2025-07-18                              152233
#  50 2025-07-19                              152181
#  51 2025-07-20                              152129
#  52 2025-07-21                              152078
#  53 2025-07-22                              152028
#  54 2025-07-23                              151978
#  55 2025-07-24                              151928
#  56 2025-07-25                              151879
#  57 2025-07-26                              151831
#  58 2025-07-27                              151783
#  59 2025-07-28                              151735
#  60 2025-07-29                              151689
#  61 2025-07-30                              151642
#  62 2025-07-31                              151596
#  63 2025-08-01                              151551
#  64 2025-08-02                              151506
#  65 2025-08-03                              151461
#  66 2025-08-04                              151417
#  67 2025-08-05                              151373
#  68 2025-08-06                              151330
#  69 2025-08-07                              151287
#  70 2025-08-08                              151245
#  71 2025-08-09                              151203
#  72 2025-08-10                              151161
#  73 2025-08-11                              151120
#  74 2025-08-12                              151079
#  75 2025-08-13                              151039
#  76 2025-08-14                              150999
#  77 2025-08-15                              150960
#  78 2025-08-16                              150921
#  79 2025-08-17                              150882
#  80 2025-08-18                              150844
#  81 2025-08-19                              150806
#  82 2025-08-20                              150768
#  83 2025-08-21                              150731
#  84 2025-08-22                              150694
#  85 2025-08-23                              150658
#  86 2025-08-24                              150621
#  87 2025-08-25                              150586
#  88 2025-08-26                              150550
#  89 2025-08-27                              150515
#  90 2025-08-28                              150480

# %% [markdown]
# Tampilkan plot harga historis 90 hari + prediksi 90 hari ke depan

# %%
window_hist = 90 # menentukan jumlah hari historis yang akan ditampilkan
last_hist_dates = df.index[-window_hist:] # mengambil tanggal historis terakhir
last_hist_prices = df['Harga'].iloc[-window_hist:] # mengambil harga historis terakhir

future_dates_90_plot = df_future_90_plot.index # mengambil tanggal untuk prediksi 90 hari ke depan
future_prices_90_plot = df_future_90_plot['Prediksi Harga Daging Sapi'] # mengambil harga prediksi 90 hari ke depan

plt.figure(figsize=(14,7)) # plot ukuran grafik
plt.plot(last_hist_dates, last_hist_prices, label=f'Harga Asli {window_hist} Hari Terakhir', color='blue') # plot harga historis terakhir
plt.plot(future_dates_90_plot, future_prices_90_plot, label='Prediksi 90 Hari Kedepan', color='orange', linestyle='--') # plot prediksi 90 hari ke depan
plt.axvline(x=last_hist_dates[-1], color='grey', linestyle=':', label='Batas Data Historis') # garis vertikal untuk batas data historis
plt.title(f'Harga Daging Sapi: {window_hist} Hari Terakhir & Prediksi 90 Hari Kedepan') # judul grafik
plt.xlabel('Tanggal') # label sumbu x
plt.ylabel('Harga') # label sumbu y
plt.xticks(rotation=45) # rotasi label sumbu x agar lebih mudah dibaca
plt.legend() # menampilkan legenda
plt.grid(True) # menampilkan grid pada grafik
plt.tight_layout() # mengatur layout grafik agar lebih rapi
plt.show() # menampilkan grafik harga daging sapi dengan prediksi 90 hari ke depan
